# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
import xgboost as xg
from xgboost import XGBRegressor


def one_hot_encode(
    df: pd.DataFrame,
    column: str,
    prefix: str,
) -> pd.DataFrame:

    df_ = df.copy()
    df_encoded = pd.get_dummies(df_[column], dtype="int")
    for col in df_encoded:
        df_[f"{prefix}_{col}"] = df_encoded[col]

    return df_.drop(columns=[column])

# %%
vuelos = pd.read_parquet("../resources/flights_clean.parquet")
ventas = pd.read_parquet("../resources/sales_clean.parquet")

# %%
# Merge a ambos dataframes
vuelos_ventas = pd.merge(ventas, vuelos, on="Flight_ID")
vuelos_ventas.drop(columns=["index", "Aeronave"], inplace=True)
vuelos_ventas
# Out:
#                                 Flight_ID  ProductType  \
# 0        a05290288259526edd3601160b10e1de      Botanas
# 1        a05290288259526edd3601160b10e1de      Botanas
# 2        a05290288259526edd3601160b10e1de      Botanas
# 3        a05290288259526edd3601160b10e1de    Refrescos
# 4        a05290288259526edd3601160b10e1de      Licores
# ...                                   ...          ...
# 2095947  6113fc0448cd548cd7e7d3f76e7872c5  Perecederos
# 2095948  78b84bc241b924d6c89e171a34b0f60c  Perecederos
# 2095949  2d7d30a16334ee2db84e5bc027a4a186      Licores
# 2095950  7a56b895719a91ca6a98004cff956b7d      Licores
# 2095951  6a73f28314810ec3033e399c2b69f99d      Licores
#
#                        ProductName  Quantity  TotalSales DepartureStation  \
# 0              Carne Seca Habanero         1        55.0               AW
# 1                          Cheetos         2        98.0               AW
# 2                    Ruffles Queso         6       294.0               AW
# 3                  Coca Sin Azucar         2        96.0               AW
# 4                    Jack And Coke         1        72.0               AW
# ...                            ...       ...         ...              ...
# 2095947     Cuerno Clasico De Pavo         5       575.0               AF
# 2095948     Cuerno Clasico De Pavo         1       115.0               AT
# 2095949  Vino Tinto Sangre De Toro         1       155.0               AO
# 2095950  Vino Tinto Sangre De Toro         1       155.0               AL
# 2095951  Vino Tinto Sangre De Toro         1       155.0               BQ
#
#         ArrivalStation     Destination_Type          Origin_Type  \
# 0                   AO     Ciudad Principal     Ciudad Principal
# 1                   AO     Ciudad Principal     Ciudad Principal
# 2                   AO     Ciudad Principal     Ciudad Principal
# 3                   AO     Ciudad Principal     Ciudad Principal
# 4                   AO     Ciudad Principal     Ciudad Principal
# ...                ...                  ...                  ...
# 2095947             AW     Ciudad Principal    Ciudad Fronteriza
# 2095948             BP  MX Amigos y Familia     Ciudad Principal
# 2095949             BD                Playa     Ciudad Principal
# 2095950             AW     Ciudad Principal  MX Amigos y Familia
# 2095951             AU           Ecoturismo  MX Amigos y Familia
#
#                         STD                 STA  Capacity  Passengers  \
# 0       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 1       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 2       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 3       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 4       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# ...                     ...                 ...       ...         ...
# 2095947 2023-11-02 23:10:00 2023-11-03 00:50:00       240       154.0
# 2095948 2023-10-05 06:00:00 2023-10-05 07:05:00       240       188.0
# 2095949 2023-05-16 18:45:00 2023-05-16 19:35:00       180       149.0
# 2095950 2023-02-15 07:00:00 2023-02-15 08:25:00       220       210.0
# 2095951 2023-05-05 17:50:00 2023-05-05 18:55:00       220       211.0
#
#          Bookings  Semana  Mes
# 0           100.0      35    8
# 1           100.0      35    8
# 2           100.0      35    8
# 3           100.0      35    8
# 4           100.0      35    8
# ...           ...     ...  ...
# 2095947     119.0      44   11
# 2095948     150.0      40   10
# 2095949     112.0      20    5
# 2095950     170.0       7    2
# 2095951     169.0      18    5
#
# [2095952 rows x 16 columns]

# %%
vuelos_ventas = vuelos_ventas.groupby("Flight_ID").agg(
    {
        "TotalSales": "sum",
        "Bookings": "mean",
        "Passengers": "mean",
        "Origin_Type": "first",
        "Destination_Type": "first",
        "STD": "first",
        "STA": "first",
        "DepartureStation": "first",
        "ArrivalStation": "first",
        "Semana": "first",
        "Mes": "first",
        "Capacity": "first",
    }
)
vuelos_ventas["STD"] = pd.to_datetime(vuelos_ventas["STD"])


vuelos_ventas["STA"] = pd.to_datetime(vuelos_ventas["STA"])


vuelos_ventas["Duracion"] = vuelos_ventas["STA"] - vuelos_ventas["STD"]


vuelos_ventas["Duracion"] = vuelos_ventas["Duracion"].dt.total_seconds() / 60


vuelos_ventas["Hora"] = vuelos_ventas["STD"].dt.hour


vuelos_ventas["Dia"] = vuelos_ventas["STD"].dt.day


# Cambiar tipos de destinos a one-hot encoding


destination_type = vuelos_ventas["Destination_Type"].map(
    {
        "Ciudad Principal": "destino_ciudadprincipal",
        "Playa": "destino_playa",
        "MX Amigos y Familia": "destino_amigosfamilia",
        "Ciudad Fronteriza": "destino_ciudadfronteriza",
        "Ecoturismo": "destino_ecoturismo",
    }
)


destination_type = pd.get_dummies(destination_type, dtype="int")


vuelos_ventas = (
    pd.concat([vuelos_ventas, destination_type], axis=1)
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)


vuelos_ventas = (
    vuelos_ventas.drop(columns=["Destination_Type"])
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)


origen_type = vuelos_ventas["Origin_Type"].map(
    {
        "Ciudad Principal": "origen_ciudadprincipal",
        "Playa": "origen_playa",
        "MX Amigos y Familia": "origen_amigosfamilia",
        "Ciudad Fronteriza": "origen_ciudadfronteriza",
        "Ecoturismo": "origen_ecoturismo",
    }
)


origen_type = pd.get_dummies(origen_type, dtype="int")


vuelos_ventas = (
    pd.concat([vuelos_ventas, origen_type], axis=1)
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)


vuelos_ventas = (
    vuelos_ventas.drop(columns=["Origin_Type"])
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)


vuelos_ventas["Book_Pass"] = vuelos_ventas["Bookings"] / vuelos_ventas["Passengers"]


vuelos_ventas.drop(columns=["STD", "STA"], inplace=True)


vuelos_ventas = one_hot_encode(vuelos_ventas, "DepartureStation", "departure")


vuelos_ventas = one_hot_encode(vuelos_ventas, "ArrivalStation", "arrival")

# %%
# Hacemos el modelo de regesion
X = vuelos_ventas.drop(columns=["TotalSales"])
y = vuelos_ventas["TotalSales"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r111 = XGBRegressor(n_estimators=10, seed=123)
xgb_r = XGBRegressor(learning_rate=0.3, n_estimators=250)
xgb_r.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r.predict(x_test)
# Out:
# [0]	validation_0-rmse:2481.74894
# [1]	validation_0-rmse:2198.97013
# [2]	validation_0-rmse:2033.32798
# [3]	validation_0-rmse:1907.75976
# [4]	validation_0-rmse:1834.64862
# [5]	validation_0-rmse:1773.85720
# [6]	validation_0-rmse:1717.03975
# [7]	validation_0-rmse:1690.80258
# [8]	validation_0-rmse:1672.18555
# [9]	validation_0-rmse:1654.92034
# [10]	validation_0-rmse:1639.77394
# [11]	validation_0-rmse:1630.80127
# [12]	validation_0-rmse:1618.72050
# [13]	validation_0-rmse:1610.92381
# [14]	validation_0-rmse:1605.80254
# [15]	validation_0-rmse:1602.88202
# [16]	validation_0-rmse:1596.54765
# [17]	validation_0-rmse:1590.12355
# [18]	validation_0-rmse:1583.64605
# [19]	validation_0-rmse:1581.56075
# [20]	validation_0-rmse:1579.30407
# [21]	validation_0-rmse:1577.54724
# [22]	validation_0-rmse:1576.87235
# [23]	validation_0-rmse:1571.83939
# [24]	validation_0-rmse:1567.25605
# [25]	validation_0-rmse:1565.76184
# [26]	validation_0-rmse:1564.85253
# [27]	validation_0-rmse:1562.18313
# [28]	validation_0-rmse:1561.84044
# [29]	validation_0-rmse:1560.16143
# [30]	validation_0-rmse:1559.18387
# [31]	validation_0-rmse:1549.17618
# [32]	validation_0-rmse:1548.72418
# [33]	validation_0-rmse:1548.22617
# [34]	validation_0-rmse:1546.02571
# [35]	validation_0-rmse:1544.19914
# [36]	validation_0-rmse:1543.72081
# [37]	validation_0-rmse:1542.38389
# [38]	validation_0-rmse:1541.60536
# [39]	validation_0-rmse:1541.55651
# [40]	validation_0-rmse:1541.28974
# [41]	validation_0-rmse:1540.73842
# [42]	validation_0-rmse:1541.02348
# [43]	validation_0-rmse:1540.25910
# [44]	validation_0-rmse:1539.42640
# [45]	validation_0-rmse:1539.00081
# [46]	validation_0-rmse:1537.79977
# [47]	validation_0-rmse:1537.97370
# [48]	validation_0-rmse:1537.26309
# [49]	validation_0-rmse:1536.89051
# [50]	validation_0-rmse:1536.44413
# [51]	validation_0-rmse:1536.00321
# [52]	validation_0-rmse:1535.86007
# [53]	validation_0-rmse:1535.67142
# [54]	validation_0-rmse:1535.39971
# [55]	validation_0-rmse:1535.17596
# [56]	validation_0-rmse:1535.33426
# [57]	validation_0-rmse:1534.98909
# [210]	validation_0-rmse:1533.56943
# [211]	validation_0-rmse:1533.74489
# [212]	validation_0-rmse:1534.16638
# [213]	validation_0-rmse:1534.52084
# [214]	validation_0-rmse:1534.74023
# [215]	validation_0-rmse:1535.13298
# [216]	validation_0-rmse:1535.12429
# [217]	validation_0-rmse:1535.23311
# [218]	validation_0-rmse:1535.67575
# [219]	validation_0-rmse:1536.05660
# [220]	validation_0-rmse:1536.01777
# [221]	validation_0-rmse:1536.19737
# [222]	validation_0-rmse:1536.19491
# [223]	validation_0-rmse:1536.28813
# [224]	validation_0-rmse:1536.48280
# [225]	validation_0-rmse:1536.52840
# [226]	validation_0-rmse:1536.50472
# [227]	validation_0-rmse:1536.32852
# [228]	validation_0-rmse:1536.73284
# [229]	validation_0-rmse:1536.77650
# [230]	validation_0-rmse:1537.40864
# [231]	validation_0-rmse:1537.30878
# [232]	validation_0-rmse:1537.38869
# [233]	validation_0-rmse:1537.28709
# [234]	validation_0-rmse:1537.28087
# [235]	validation_0-rmse:1537.65264
# [236]	validation_0-rmse:1538.03323
# [237]	validation_0-rmse:1538.12138
# [238]	validation_0-rmse:1538.11164
# [239]	validation_0-rmse:1538.26091
# [240]	validation_0-rmse:1538.36280
# [241]	validation_0-rmse:1538.39622
# [242]	validation_0-rmse:1538.41820
# [243]	validation_0-rmse:1538.56701
# [244]	validation_0-rmse:1538.37236
# [245]	validation_0-rmse:1538.41141
# [246]	validation_0-rmse:1538.36508
# [247]	validation_0-rmse:1538.67588
# [248]	validation_0-rmse:1538.95397
# [249]	validation_0-rmse:1538.40436

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7157283740835436
# Mean Absolute Error: 976.2706119747071
# Mean Squared Error: 2366687.9791630553
# Root Mean Squared Error: 1538.4043613962667
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Modelo cantidad**

# %%
# Merge a ambos dataframes
vuelos_ventas = pd.merge(ventas, vuelos, on="Flight_ID")
vuelos_ventas.drop(columns=["index", "Aeronave"], inplace=True)

# %%
vuelos_ventas["STD"] = pd.to_datetime(vuelos_ventas["STD"])
vuelos_ventas["STA"] = pd.to_datetime(vuelos_ventas["STA"])
vuelos_ventas["Duracion"] = vuelos_ventas["STA"] - vuelos_ventas["STD"]
vuelos_ventas["Duracion"] = vuelos_ventas["Duracion"].dt.total_seconds() / 60
vuelos_ventas["Hora"] = vuelos_ventas["STD"].dt.hour
vuelos_ventas["Dia"] = vuelos_ventas["STD"].dt.day
# Cambiar tipos de destinos a one-hot encoding
destination_type = vuelos_ventas["Destination_Type"].map(
    {
        "Ciudad Principal": "destino_ciudadprincipal",
        "Playa": "destino_playa",
        "MX Amigos y Familia": "destino_amigosfamilia",
        "Ciudad Fronteriza": "destino_ciudadfronteriza",
        "Ecoturismo": "destino_ecoturismo",
    }
)
destination_type = pd.get_dummies(destination_type, dtype="int")
vuelos_ventas = (
    pd.concat([vuelos_ventas, destination_type], axis=1)
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas = (
    vuelos_ventas.drop(columns=["Destination_Type"])
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
origen_type = vuelos_ventas["Origin_Type"].map(
    {
        "Ciudad Principal": "origen_ciudadprincipal",
        "Playa": "origen_playa",
        "MX Amigos y Familia": "origen_amigosfamilia",
        "Ciudad Fronteriza": "origen_ciudadfronteriza",
        "Ecoturismo": "origen_ecoturismo",
    }
)
origen_type = pd.get_dummies(origen_type, dtype="int")
vuelos_ventas = (
    pd.concat([vuelos_ventas, origen_type], axis=1)
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas = (
    vuelos_ventas.drop(columns=["Origin_Type"])
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas["Book_Pass"] = vuelos_ventas["Bookings"] / vuelos_ventas["Passengers"]
vuelos_ventas.drop(columns=["STD", "STA"], inplace=True)
vuelos_ventas = one_hot_encode(vuelos_ventas, "DepartureStation", "departure")
vuelos_ventas = one_hot_encode(vuelos_ventas, "ArrivalStation", "arrival")

# %%
vuelos_ventas.drop(columns=["Flight_ID", "ProductType", "TotalSales"], inplace=True)

# %%
product_dict = {}
for i in vuelos_ventas["ProductName"].unique():
    product_dict[i] = len(product_dict)
vuelos_ventas["ProductName"] = vuelos_ventas["ProductName"].map(product_dict)
product_dict_inv = {val: key for key, val in product_dict.items()}

# %%
# Encontrar los productos mas vendidos
product_sales = vuelos_ventas.groupby("ProductName")["Quantity"].sum()
product_sales = product_sales.sort_values(ascending=False)
top10 = product_sales.index[:10]
print([product_dict_inv[i] for i in top10])
# Out:
# ['Coca Cola Regular', 'Agua Natural 600 Ml', 'Sabritas Originales', 'Ruffles Queso', 'Doritos Nacho', 'Panini Clasico', 'Fritos Limon Y Sal', 'Sabritas Flamin Hot', 'Sprite', 'Cheetos']

# %% [markdown]
# ## **Coca**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[0]]

# %%
vuelos_ventas.groupby("ProductName")["Quantity"].median()[9]
# Out:
# 5.0

# %%
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r2 = XGBRegressor(n_estimators=10, seed=123)
xgb_r1 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r1.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r1.predict(x_test)
# Out:
# [0]	validation_0-rmse:5.25927
# [1]	validation_0-rmse:4.83643
# [2]	validation_0-rmse:4.66404
# [3]	validation_0-rmse:4.57700
# [4]	validation_0-rmse:4.52000
# [5]	validation_0-rmse:4.47930
# [6]	validation_0-rmse:4.44579
# [7]	validation_0-rmse:4.42145
# [8]	validation_0-rmse:4.41315
# [9]	validation_0-rmse:4.39696
# [10]	validation_0-rmse:4.38211
# [11]	validation_0-rmse:4.37732
# [12]	validation_0-rmse:4.37356
# [13]	validation_0-rmse:4.37078
# [14]	validation_0-rmse:4.36820
# [15]	validation_0-rmse:4.36888
# [16]	validation_0-rmse:4.36470
# [17]	validation_0-rmse:4.35684
# [18]	validation_0-rmse:4.35384
# [19]	validation_0-rmse:4.35331
# [20]	validation_0-rmse:4.34916
# [21]	validation_0-rmse:4.34651
# [22]	validation_0-rmse:4.34613
# [23]	validation_0-rmse:4.34210
# [24]	validation_0-rmse:4.34017
# [25]	validation_0-rmse:4.33944
# [26]	validation_0-rmse:4.33941
# [27]	validation_0-rmse:4.33697
# [28]	validation_0-rmse:4.33992
# [29]	validation_0-rmse:4.33941
# [30]	validation_0-rmse:4.33684
# [31]	validation_0-rmse:4.33597
# [32]	validation_0-rmse:4.33255
# [33]	validation_0-rmse:4.33223
# [34]	validation_0-rmse:4.33008
# [35]	validation_0-rmse:4.32893
# [36]	validation_0-rmse:4.32951
# [37]	validation_0-rmse:4.33110
# [38]	validation_0-rmse:4.32841
# [39]	validation_0-rmse:4.32611
# [40]	validation_0-rmse:4.32429
# [41]	validation_0-rmse:4.32334
# [42]	validation_0-rmse:4.32138
# [43]	validation_0-rmse:4.32041
# [44]	validation_0-rmse:4.32438
# [45]	validation_0-rmse:4.32555
# [46]	validation_0-rmse:4.32416
# [47]	validation_0-rmse:4.32490
# [48]	validation_0-rmse:4.32469
# [49]	validation_0-rmse:4.32382
# [50]	validation_0-rmse:4.32523
# [51]	validation_0-rmse:4.32692
# [52]	validation_0-rmse:4.32831
# [53]	validation_0-rmse:4.33137
# [54]	validation_0-rmse:4.33228
# [55]	validation_0-rmse:4.33277
# [56]	validation_0-rmse:4.33261
# [57]	validation_0-rmse:4.33295
# [58]	validation_0-rmse:4.33277
# [59]	validation_0-rmse:4.33226
# [60]	validation_0-rmse:4.33372
# [61]	validation_0-rmse:4.33275
# [62]	validation_0-rmse:4.33330
# [63]	validation_0-rmse:4.33451
# [64]	validation_0-rmse:4.33426
# [65]	validation_0-rmse:4.33494
# [66]	validation_0-rmse:4.33605
# [67]	validation_0-rmse:4.33563
# [68]	validation_0-rmse:4.33566
# [69]	validation_0-rmse:4.33543
# [70]	validation_0-rmse:4.33558
# [71]	validation_0-rmse:4.33585
# [72]	validation_0-rmse:4.33904
# [73]	validation_0-rmse:4.34026
# [74]	validation_0-rmse:4.34078
# [75]	validation_0-rmse:4.34080
# [76]	validation_0-rmse:4.34320
# [77]	validation_0-rmse:4.34476
# [78]	validation_0-rmse:4.34692
# [79]	validation_0-rmse:4.34644
# [80]	validation_0-rmse:4.34810
# [81]	validation_0-rmse:4.34797
# [82]	validation_0-rmse:4.34995
# [83]	validation_0-rmse:4.35021
# [84]	validation_0-rmse:4.35159
# [85]	validation_0-rmse:4.35214
# [86]	validation_0-rmse:4.35258
# [87]	validation_0-rmse:4.35431
# [88]	validation_0-rmse:4.35723
# [89]	validation_0-rmse:4.35802
# [90]	validation_0-rmse:4.35959
# [91]	validation_0-rmse:4.35953
# [92]	validation_0-rmse:4.35994
# [93]	validation_0-rmse:4.36175
# [94]	validation_0-rmse:4.36181
# [95]	validation_0-rmse:4.36428
# [96]	validation_0-rmse:4.36529
# [97]	validation_0-rmse:4.36651
# [98]	validation_0-rmse:4.36697
# [99]	validation_0-rmse:4.36731
# [100]	validation_0-rmse:4.36790
# [101]	validation_0-rmse:4.36805
# [102]	validation_0-rmse:4.36905
# [103]	validation_0-rmse:4.36965
# [104]	validation_0-rmse:4.37029
# [105]	validation_0-rmse:4.37088
# [106]	validation_0-rmse:4.37348
# [107]	validation_0-rmse:4.37438
# [108]	validation_0-rmse:4.37424
# [109]	validation_0-rmse:4.37511
# [110]	validation_0-rmse:4.37722
# [111]	validation_0-rmse:4.37718
# [112]	validation_0-rmse:4.37650
# [113]	validation_0-rmse:4.37711
# [114]	validation_0-rmse:4.37854
# [115]	validation_0-rmse:4.37956
# [116]	validation_0-rmse:4.38092
# [117]	validation_0-rmse:4.38341
# [118]	validation_0-rmse:4.38436
# [119]	validation_0-rmse:4.38618
# [120]	validation_0-rmse:4.38630
# [121]	validation_0-rmse:4.38627
# [122]	validation_0-rmse:4.38758
# [123]	validation_0-rmse:4.38845
# [124]	validation_0-rmse:4.39042
# [125]	validation_0-rmse:4.39004
# [126]	validation_0-rmse:4.39102
# [127]	validation_0-rmse:4.39282
# [128]	validation_0-rmse:4.39600
# [129]	validation_0-rmse:4.39590
# [130]	validation_0-rmse:4.39819
# [131]	validation_0-rmse:4.39936
# [132]	validation_0-rmse:4.40143
# [133]	validation_0-rmse:4.40399
# [134]	validation_0-rmse:4.40393
# [135]	validation_0-rmse:4.40400
# [136]	validation_0-rmse:4.40568
# [137]	validation_0-rmse:4.40833
# [138]	validation_0-rmse:4.40945
# [139]	validation_0-rmse:4.40921
# [140]	validation_0-rmse:4.40913
# [141]	validation_0-rmse:4.41052
# [142]	validation_0-rmse:4.41136
# [143]	validation_0-rmse:4.41169
# [144]	validation_0-rmse:4.41258
# [145]	validation_0-rmse:4.41435
# [146]	validation_0-rmse:4.41420
# [147]	validation_0-rmse:4.41544
# [148]	validation_0-rmse:4.41658
# [149]	validation_0-rmse:4.41750
# [150]	validation_0-rmse:4.41847
# [151]	validation_0-rmse:4.41996
# [152]	validation_0-rmse:4.42132
# [153]	validation_0-rmse:4.42160
# [154]	validation_0-rmse:4.42259
# [155]	validation_0-rmse:4.42200
# [156]	validation_0-rmse:4.42273
# [157]	validation_0-rmse:4.42341
# [158]	validation_0-rmse:4.42346
# [159]	validation_0-rmse:4.42370
# [160]	validation_0-rmse:4.42414
# [161]	validation_0-rmse:4.42507
# [162]	validation_0-rmse:4.42524
# [163]	validation_0-rmse:4.42560
# [164]	validation_0-rmse:4.42742
# [165]	validation_0-rmse:4.42823
# [166]	validation_0-rmse:4.43173
# [167]	validation_0-rmse:4.43360
# [168]	validation_0-rmse:4.43416
# [169]	validation_0-rmse:4.43486
# [170]	validation_0-rmse:4.43573
# [171]	validation_0-rmse:4.43614
# [172]	validation_0-rmse:4.43641
# [173]	validation_0-rmse:4.43780
# [174]	validation_0-rmse:4.43806
# [175]	validation_0-rmse:4.43897
# [176]	validation_0-rmse:4.43878
# [177]	validation_0-rmse:4.43924
# [178]	validation_0-rmse:4.44119
# [179]	validation_0-rmse:4.44228
# [180]	validation_0-rmse:4.44316
# [181]	validation_0-rmse:4.44280
# [182]	validation_0-rmse:4.44391
# [183]	validation_0-rmse:4.44392
# [184]	validation_0-rmse:4.44363
# [185]	validation_0-rmse:4.44315
# [186]	validation_0-rmse:4.44418
# [187]	validation_0-rmse:4.44586
# [188]	validation_0-rmse:4.44655
# [189]	validation_0-rmse:4.44765
# [190]	validation_0-rmse:4.45056
# [191]	validation_0-rmse:4.45188
# [192]	validation_0-rmse:4.45184
# [193]	validation_0-rmse:4.45237
# [194]	validation_0-rmse:4.45218
# [195]	validation_0-rmse:4.45250
# [196]	validation_0-rmse:4.45304
# [197]	validation_0-rmse:4.45409
# [198]	validation_0-rmse:4.45451
# [199]	validation_0-rmse:4.45542
# [200]	validation_0-rmse:4.45608
# [201]	validation_0-rmse:4.45689
# [202]	validation_0-rmse:4.45816
# [203]	validation_0-rmse:4.45920
# [204]	validation_0-rmse:4.46044
# [205]	validation_0-rmse:4.46057
# [206]	validation_0-rmse:4.46210
# [207]	validation_0-rmse:4.46334
# [208]	validation_0-rmse:4.46494
# [209]	validation_0-rmse:4.46464
# [210]	validation_0-rmse:4.46614
# [211]	validation_0-rmse:4.46683
# [212]	validation_0-rmse:4.46800
# [213]	validation_0-rmse:4.46856
# [214]	validation_0-rmse:4.46914
# [215]	validation_0-rmse:4.46978
# [216]	validation_0-rmse:4.47107
# [217]	validation_0-rmse:4.47215
# [218]	validation_0-rmse:4.47401
# [219]	validation_0-rmse:4.47403
# [220]	validation_0-rmse:4.47516
# [221]	validation_0-rmse:4.47666
# [222]	validation_0-rmse:4.47762
# [223]	validation_0-rmse:4.47775
# [224]	validation_0-rmse:4.47812
# [225]	validation_0-rmse:4.47848
# [226]	validation_0-rmse:4.47906
# [227]	validation_0-rmse:4.47947
# [228]	validation_0-rmse:4.48037
# [229]	validation_0-rmse:4.48026
# [230]	validation_0-rmse:4.48103
# [231]	validation_0-rmse:4.48149
# [232]	validation_0-rmse:4.48237
# [233]	validation_0-rmse:4.48321
# [234]	validation_0-rmse:4.48374
# [235]	validation_0-rmse:4.48686
# [236]	validation_0-rmse:4.48819
# [237]	validation_0-rmse:4.48873
# [238]	validation_0-rmse:4.48882
# [239]	validation_0-rmse:4.49104
# [240]	validation_0-rmse:4.49175
# [241]	validation_0-rmse:4.49452
# [242]	validation_0-rmse:4.49479
# [243]	validation_0-rmse:4.49696
# [244]	validation_0-rmse:4.49820
# [245]	validation_0-rmse:4.49839
# [246]	validation_0-rmse:4.49990
# [247]	validation_0-rmse:4.50109
# [248]	validation_0-rmse:4.50133
# [249]	validation_0-rmse:4.50234

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print(
    "Root Mean Squared Error:",
    np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
)
# Out:
# R2 Score: 0.47195014894970644
# Mean Absolute Error: 3.168193698105979
# Mean Squared Error: 20.271020487713272
# Root Mean Squared Error: 4.502335003941097
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Agua**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[1]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r3 = XGBRegressor(n_estimators=10, seed=123)
xgb_r2 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r2.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r2.predict(x_test)
# Out:
# [0]	validation_0-rmse:4.30768
# [1]	validation_0-rmse:4.04691
# [2]	validation_0-rmse:3.91754
# [3]	validation_0-rmse:3.84463
# [4]	validation_0-rmse:3.79234
# [5]	validation_0-rmse:3.75874
# [6]	validation_0-rmse:3.71758
# [7]	validation_0-rmse:3.70004
# [8]	validation_0-rmse:3.67621
# [9]	validation_0-rmse:3.66835
# [10]	validation_0-rmse:3.65938
# [11]	validation_0-rmse:3.64529
# [12]	validation_0-rmse:3.64204
# [13]	validation_0-rmse:3.63853
# [14]	validation_0-rmse:3.61599
# [15]	validation_0-rmse:3.61022
# [16]	validation_0-rmse:3.60892
# [17]	validation_0-rmse:3.60757
# [18]	validation_0-rmse:3.60263
# [19]	validation_0-rmse:3.60102
# [20]	validation_0-rmse:3.60014
# [21]	validation_0-rmse:3.59906
# [22]	validation_0-rmse:3.59715
# [23]	validation_0-rmse:3.59597
# [24]	validation_0-rmse:3.59415
# [25]	validation_0-rmse:3.59460
# [26]	validation_0-rmse:3.59284
# [27]	validation_0-rmse:3.58630
# [28]	validation_0-rmse:3.58567
# [29]	validation_0-rmse:3.58463
# [30]	validation_0-rmse:3.58449
# [31]	validation_0-rmse:3.58180
# [32]	validation_0-rmse:3.58122
# [33]	validation_0-rmse:3.58055
# [34]	validation_0-rmse:3.58057
# [35]	validation_0-rmse:3.58182
# [36]	validation_0-rmse:3.58144
# [37]	validation_0-rmse:3.58031
# [38]	validation_0-rmse:3.58129
# [39]	validation_0-rmse:3.58111
# [40]	validation_0-rmse:3.58347
# [41]	validation_0-rmse:3.58278
# [42]	validation_0-rmse:3.58141
# [43]	validation_0-rmse:3.58080
# [44]	validation_0-rmse:3.58132
# [45]	validation_0-rmse:3.58211
# [46]	validation_0-rmse:3.57711
# [47]	validation_0-rmse:3.57668
# [48]	validation_0-rmse:3.57930
# [49]	validation_0-rmse:3.57950
# [50]	validation_0-rmse:3.58007
# [51]	validation_0-rmse:3.57925
# [52]	validation_0-rmse:3.57967
# [213]	validation_0-rmse:3.69195
# [214]	validation_0-rmse:3.69291
# [215]	validation_0-rmse:3.69395
# [216]	validation_0-rmse:3.69544
# [217]	validation_0-rmse:3.69590
# [218]	validation_0-rmse:3.69610
# [219]	validation_0-rmse:3.69745
# [220]	validation_0-rmse:3.69814
# [221]	validation_0-rmse:3.69868
# [222]	validation_0-rmse:3.69925
# [223]	validation_0-rmse:3.70076
# [224]	validation_0-rmse:3.70053
# [225]	validation_0-rmse:3.70116
# [226]	validation_0-rmse:3.70062
# [227]	validation_0-rmse:3.70090
# [228]	validation_0-rmse:3.70258
# [229]	validation_0-rmse:3.70322
# [230]	validation_0-rmse:3.70407
# [231]	validation_0-rmse:3.70413
# [232]	validation_0-rmse:3.70433
# [233]	validation_0-rmse:3.70495
# [234]	validation_0-rmse:3.70592
# [235]	validation_0-rmse:3.70741
# [236]	validation_0-rmse:3.70761
# [237]	validation_0-rmse:3.70832
# [238]	validation_0-rmse:3.70894
# [239]	validation_0-rmse:3.71017
# [240]	validation_0-rmse:3.71063
# [241]	validation_0-rmse:3.71096
# [242]	validation_0-rmse:3.71138
# [243]	validation_0-rmse:3.71107
# [244]	validation_0-rmse:3.71173
# [245]	validation_0-rmse:3.71246
# [246]	validation_0-rmse:3.71274
# [247]	validation_0-rmse:3.71325
# [248]	validation_0-rmse:3.71394
# [249]	validation_0-rmse:3.71405

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.4365865655890262
# Mean Absolute Error: 2.6145307317859143
# Mean Squared Error: 13.794136460462491
# Root Mean Squared Error: 3.7140458344590326
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Sabritas Originales**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[2]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r4 = XGBRegressor(n_estimators=10, seed=123)
xgb_r3 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r3.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r3.predict(x_test)
# Out:
# [0]	validation_0-rmse:2.91804
# [1]	validation_0-rmse:2.75313
# [2]	validation_0-rmse:2.67716
# [3]	validation_0-rmse:2.63141
# [4]	validation_0-rmse:2.60938
# [5]	validation_0-rmse:2.59443
# [6]	validation_0-rmse:2.58884
# [7]	validation_0-rmse:2.58248
# [8]	validation_0-rmse:2.57777
# [9]	validation_0-rmse:2.57351
# [10]	validation_0-rmse:2.57328
# [11]	validation_0-rmse:2.57013
# [12]	validation_0-rmse:2.56850
# [13]	validation_0-rmse:2.56779
# [14]	validation_0-rmse:2.56734
# [15]	validation_0-rmse:2.56630
# [16]	validation_0-rmse:2.56713
# [17]	validation_0-rmse:2.56775
# [18]	validation_0-rmse:2.56782
# [19]	validation_0-rmse:2.56895
# [20]	validation_0-rmse:2.56828
# [21]	validation_0-rmse:2.56505
# [22]	validation_0-rmse:2.56335
# [23]	validation_0-rmse:2.56416
# [24]	validation_0-rmse:2.56410
# [25]	validation_0-rmse:2.56403
# [26]	validation_0-rmse:2.56509
# [27]	validation_0-rmse:2.56528
# [28]	validation_0-rmse:2.56511
# [29]	validation_0-rmse:2.56535
# [30]	validation_0-rmse:2.56691
# [31]	validation_0-rmse:2.56656
# [32]	validation_0-rmse:2.56805
# [33]	validation_0-rmse:2.56820
# [34]	validation_0-rmse:2.56976
# [35]	validation_0-rmse:2.57123
# [36]	validation_0-rmse:2.57145
# [37]	validation_0-rmse:2.57191
# [38]	validation_0-rmse:2.57173
# [39]	validation_0-rmse:2.57186
# [40]	validation_0-rmse:2.57275
# [41]	validation_0-rmse:2.57287
# [42]	validation_0-rmse:2.57368
# [43]	validation_0-rmse:2.57550
# [44]	validation_0-rmse:2.57701
# [45]	validation_0-rmse:2.57667
# [46]	validation_0-rmse:2.57805
# [47]	validation_0-rmse:2.57871
# [48]	validation_0-rmse:2.58107
# [49]	validation_0-rmse:2.58178
# [50]	validation_0-rmse:2.58187
# [51]	validation_0-rmse:2.58168
# [52]	validation_0-rmse:2.58237
# [53]	validation_0-rmse:2.58375
# [54]	validation_0-rmse:2.58444
# [55]	validation_0-rmse:2.58477
# [56]	validation_0-rmse:2.58687
# [57]	validation_0-rmse:2.58693
# [58]	validation_0-rmse:2.58741
# [59]	validation_0-rmse:2.58750
# [60]	validation_0-rmse:2.58781
# [61]	validation_0-rmse:2.58894
# [62]	validation_0-rmse:2.58876
# [63]	validation_0-rmse:2.58918
# [64]	validation_0-rmse:2.59110
# [65]	validation_0-rmse:2.59243
# [66]	validation_0-rmse:2.59250
# [67]	validation_0-rmse:2.59294
# [68]	validation_0-rmse:2.59445
# [69]	validation_0-rmse:2.59583
# [70]	validation_0-rmse:2.59609
# [71]	validation_0-rmse:2.59705
# [72]	validation_0-rmse:2.59841
# [73]	validation_0-rmse:2.59990
# [74]	validation_0-rmse:2.60057
# [75]	validation_0-rmse:2.60141
# [76]	validation_0-rmse:2.60268
# [77]	validation_0-rmse:2.60377
# [78]	validation_0-rmse:2.60389
# [79]	validation_0-rmse:2.60401
# [80]	validation_0-rmse:2.60477
# [81]	validation_0-rmse:2.60422
# [82]	validation_0-rmse:2.60580
# [83]	validation_0-rmse:2.60684
# [84]	validation_0-rmse:2.60751
# [85]	validation_0-rmse:2.60846
# [86]	validation_0-rmse:2.61070
# [87]	validation_0-rmse:2.61123
# [88]	validation_0-rmse:2.61140
# [89]	validation_0-rmse:2.61156
# [90]	validation_0-rmse:2.61264
# [91]	validation_0-rmse:2.61386
# [92]	validation_0-rmse:2.61380
# [93]	validation_0-rmse:2.61491
# [94]	validation_0-rmse:2.61542
# [95]	validation_0-rmse:2.61704
# [96]	validation_0-rmse:2.61681
# [97]	validation_0-rmse:2.61697
# [98]	validation_0-rmse:2.61663
# [99]	validation_0-rmse:2.61739
# [100]	validation_0-rmse:2.61871
# [101]	validation_0-rmse:2.62018
# [102]	validation_0-rmse:2.62050
# [103]	validation_0-rmse:2.62103
# [104]	validation_0-rmse:2.62206
# [105]	validation_0-rmse:2.62229
# [106]	validation_0-rmse:2.62318
# [107]	validation_0-rmse:2.62406
# [108]	validation_0-rmse:2.62569
# [109]	validation_0-rmse:2.62677
# [110]	validation_0-rmse:2.62772
# [111]	validation_0-rmse:2.62812
# [112]	validation_0-rmse:2.62869
# [113]	validation_0-rmse:2.62890
# [114]	validation_0-rmse:2.62952
# [115]	validation_0-rmse:2.62984
# [116]	validation_0-rmse:2.63041
# [117]	validation_0-rmse:2.63130
# [118]	validation_0-rmse:2.63215
# [119]	validation_0-rmse:2.63288
# [120]	validation_0-rmse:2.63413
# [121]	validation_0-rmse:2.63481
# [122]	validation_0-rmse:2.63447
# [123]	validation_0-rmse:2.63533
# [124]	validation_0-rmse:2.63570
# [125]	validation_0-rmse:2.63526
# [126]	validation_0-rmse:2.63557
# [127]	validation_0-rmse:2.63551
# [128]	validation_0-rmse:2.63586
# [129]	validation_0-rmse:2.63699
# [130]	validation_0-rmse:2.63741
# [131]	validation_0-rmse:2.63832
# [132]	validation_0-rmse:2.63861
# [133]	validation_0-rmse:2.63847
# [134]	validation_0-rmse:2.63843
# [135]	validation_0-rmse:2.63922
# [136]	validation_0-rmse:2.63947
# [137]	validation_0-rmse:2.63997
# [138]	validation_0-rmse:2.64012
# [139]	validation_0-rmse:2.64053
# [140]	validation_0-rmse:2.64205
# [141]	validation_0-rmse:2.64275
# [142]	validation_0-rmse:2.64306
# [143]	validation_0-rmse:2.64355
# [144]	validation_0-rmse:2.64404
# [145]	validation_0-rmse:2.64440
# [146]	validation_0-rmse:2.64576
# [147]	validation_0-rmse:2.64639
# [148]	validation_0-rmse:2.64653
# [149]	validation_0-rmse:2.64696
# [150]	validation_0-rmse:2.64714
# [151]	validation_0-rmse:2.64713
# [152]	validation_0-rmse:2.64749
# [153]	validation_0-rmse:2.64802
# [154]	validation_0-rmse:2.64929
# [155]	validation_0-rmse:2.64948
# [156]	validation_0-rmse:2.64988
# [157]	validation_0-rmse:2.64984
# [158]	validation_0-rmse:2.65040
# [159]	validation_0-rmse:2.65109
# [160]	validation_0-rmse:2.65173
# [161]	validation_0-rmse:2.65182
# [162]	validation_0-rmse:2.65260
# [163]	validation_0-rmse:2.65295
# [164]	validation_0-rmse:2.65307
# [165]	validation_0-rmse:2.65428
# [166]	validation_0-rmse:2.65528
# [167]	validation_0-rmse:2.65667
# [168]	validation_0-rmse:2.65738
# [169]	validation_0-rmse:2.65754
# [170]	validation_0-rmse:2.65826
# [171]	validation_0-rmse:2.65960
# [172]	validation_0-rmse:2.65992
# [173]	validation_0-rmse:2.65984
# [174]	validation_0-rmse:2.66118
# [175]	validation_0-rmse:2.66190
# [176]	validation_0-rmse:2.66164
# [177]	validation_0-rmse:2.66285
# [178]	validation_0-rmse:2.66296
# [179]	validation_0-rmse:2.66329
# [180]	validation_0-rmse:2.66405
# [181]	validation_0-rmse:2.66573
# [182]	validation_0-rmse:2.66587
# [183]	validation_0-rmse:2.66729
# [184]	validation_0-rmse:2.66803
# [185]	validation_0-rmse:2.66823
# [186]	validation_0-rmse:2.66818
# [187]	validation_0-rmse:2.66865
# [188]	validation_0-rmse:2.66887
# [189]	validation_0-rmse:2.66947
# [190]	validation_0-rmse:2.66998
# [191]	validation_0-rmse:2.67070
# [192]	validation_0-rmse:2.67146
# [193]	validation_0-rmse:2.67249
# [194]	validation_0-rmse:2.67367
# [195]	validation_0-rmse:2.67435
# [196]	validation_0-rmse:2.67553
# [197]	validation_0-rmse:2.67582
# [198]	validation_0-rmse:2.67660
# [199]	validation_0-rmse:2.67741
# [200]	validation_0-rmse:2.67964
# [201]	validation_0-rmse:2.68027
# [202]	validation_0-rmse:2.68046
# [203]	validation_0-rmse:2.68084
# [204]	validation_0-rmse:2.68143
# [205]	validation_0-rmse:2.68192
# [206]	validation_0-rmse:2.68247
# [207]	validation_0-rmse:2.68272
# [208]	validation_0-rmse:2.68341
# [209]	validation_0-rmse:2.68373
# [210]	validation_0-rmse:2.68488
# [211]	validation_0-rmse:2.68517
# [212]	validation_0-rmse:2.68601
# [213]	validation_0-rmse:2.68682
# [214]	validation_0-rmse:2.68707
# [215]	validation_0-rmse:2.68693
# [216]	validation_0-rmse:2.68715
# [217]	validation_0-rmse:2.68780
# [218]	validation_0-rmse:2.68851
# [219]	validation_0-rmse:2.68945
# [220]	validation_0-rmse:2.68951
# [221]	validation_0-rmse:2.69013
# [222]	validation_0-rmse:2.69070
# [223]	validation_0-rmse:2.69110
# [224]	validation_0-rmse:2.69155
# [225]	validation_0-rmse:2.69191
# [226]	validation_0-rmse:2.69220
# [227]	validation_0-rmse:2.69205
# [228]	validation_0-rmse:2.69263
# [229]	validation_0-rmse:2.69367
# [230]	validation_0-rmse:2.69367
# [231]	validation_0-rmse:2.69456
# [232]	validation_0-rmse:2.69465
# [233]	validation_0-rmse:2.69535
# [234]	validation_0-rmse:2.69550
# [235]	validation_0-rmse:2.69563
# [236]	validation_0-rmse:2.69591
# [237]	validation_0-rmse:2.69700
# [238]	validation_0-rmse:2.69757
# [239]	validation_0-rmse:2.69780
# [240]	validation_0-rmse:2.69789
# [241]	validation_0-rmse:2.69806
# [242]	validation_0-rmse:2.69849
# [243]	validation_0-rmse:2.69940
# [244]	validation_0-rmse:2.70044
# [245]	validation_0-rmse:2.69992
# [246]	validation_0-rmse:2.70035
# [247]	validation_0-rmse:2.70043
# [248]	validation_0-rmse:2.70086
# [249]	validation_0-rmse:2.70096

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.3314282488274055
# Mean Absolute Error: 1.9254828933585648
# Mean Squared Error: 7.2951961908425185
# Root Mean Squared Error: 2.700962086154213
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Ruffles Queso**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[3]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r5 = XGBRegressor(n_estimators=10, seed=123)
xgb_r4 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r4.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r4.predict(x_test)
# Out:
# [0]	validation_0-rmse:2.52083
# [1]	validation_0-rmse:2.36275
# [2]	validation_0-rmse:2.30511
# [3]	validation_0-rmse:2.27700
# [4]	validation_0-rmse:2.25893
# [5]	validation_0-rmse:2.24515
# [6]	validation_0-rmse:2.23995
# [7]	validation_0-rmse:2.23067
# [8]	validation_0-rmse:2.22466
# [9]	validation_0-rmse:2.21904
# [10]	validation_0-rmse:2.21252
# [11]	validation_0-rmse:2.21176
# [12]	validation_0-rmse:2.21150
# [13]	validation_0-rmse:2.21062
# [14]	validation_0-rmse:2.21018
# [15]	validation_0-rmse:2.20850
# [16]	validation_0-rmse:2.20734
# [17]	validation_0-rmse:2.20538
# [18]	validation_0-rmse:2.20591
# [19]	validation_0-rmse:2.20734
# [20]	validation_0-rmse:2.20644
# [21]	validation_0-rmse:2.20530
# [22]	validation_0-rmse:2.20591
# [23]	validation_0-rmse:2.20508
# [24]	validation_0-rmse:2.20549
# [25]	validation_0-rmse:2.20555
# [26]	validation_0-rmse:2.20559
# [27]	validation_0-rmse:2.20608
# [28]	validation_0-rmse:2.20669
# [29]	validation_0-rmse:2.20703
# [30]	validation_0-rmse:2.20701
# [31]	validation_0-rmse:2.20817
# [32]	validation_0-rmse:2.20769
# [33]	validation_0-rmse:2.20731
# [34]	validation_0-rmse:2.20560
# [35]	validation_0-rmse:2.20514
# [36]	validation_0-rmse:2.20686
# [37]	validation_0-rmse:2.20786
# [38]	validation_0-rmse:2.20938
# [39]	validation_0-rmse:2.20939
# [40]	validation_0-rmse:2.21018
# [41]	validation_0-rmse:2.21069
# [42]	validation_0-rmse:2.21025
# [43]	validation_0-rmse:2.21044
# [44]	validation_0-rmse:2.21125
# [45]	validation_0-rmse:2.21174
# [46]	validation_0-rmse:2.21228
# [47]	validation_0-rmse:2.21207
# [48]	validation_0-rmse:2.21248
# [49]	validation_0-rmse:2.21439
# [50]	validation_0-rmse:2.21499
# [51]	validation_0-rmse:2.21441
# [52]	validation_0-rmse:2.21524
# [53]	validation_0-rmse:2.21568
# [54]	validation_0-rmse:2.21620
# [55]	validation_0-rmse:2.21484
# [56]	validation_0-rmse:2.21615
# [57]	validation_0-rmse:2.21637
# [58]	validation_0-rmse:2.21687
# [59]	validation_0-rmse:2.21885
# [60]	validation_0-rmse:2.22060
# [61]	validation_0-rmse:2.22292
# [62]	validation_0-rmse:2.22406
# [63]	validation_0-rmse:2.22458
# [64]	validation_0-rmse:2.22541
# [65]	validation_0-rmse:2.22556
# [66]	validation_0-rmse:2.22602
# [67]	validation_0-rmse:2.22635
# [68]	validation_0-rmse:2.22675
# [69]	validation_0-rmse:2.22673
# [70]	validation_0-rmse:2.22608
# [71]	validation_0-rmse:2.22678
# [72]	validation_0-rmse:2.22654
# [73]	validation_0-rmse:2.22744
# [74]	validation_0-rmse:2.22769
# [75]	validation_0-rmse:2.22789
# [76]	validation_0-rmse:2.22815
# [77]	validation_0-rmse:2.22864
# [78]	validation_0-rmse:2.22891
# [79]	validation_0-rmse:2.22949
# [80]	validation_0-rmse:2.23049
# [81]	validation_0-rmse:2.23198
# [82]	validation_0-rmse:2.23213
# [83]	validation_0-rmse:2.23265
# [84]	validation_0-rmse:2.23287
# [85]	validation_0-rmse:2.23252
# [86]	validation_0-rmse:2.23383
# [87]	validation_0-rmse:2.23718
# [88]	validation_0-rmse:2.23771
# [89]	validation_0-rmse:2.23958
# [90]	validation_0-rmse:2.24054
# [91]	validation_0-rmse:2.24085
# [92]	validation_0-rmse:2.24081
# [93]	validation_0-rmse:2.24254
# [94]	validation_0-rmse:2.24294
# [95]	validation_0-rmse:2.24235
# [96]	validation_0-rmse:2.24328
# [97]	validation_0-rmse:2.24439
# [98]	validation_0-rmse:2.24523
# [99]	validation_0-rmse:2.24516
# [100]	validation_0-rmse:2.24521
# [101]	validation_0-rmse:2.24601
# [102]	validation_0-rmse:2.24579
# [103]	validation_0-rmse:2.24595
# [104]	validation_0-rmse:2.24637
# [105]	validation_0-rmse:2.24688
# [106]	validation_0-rmse:2.24763
# [107]	validation_0-rmse:2.24785
# [108]	validation_0-rmse:2.24840
# [109]	validation_0-rmse:2.24884
# [110]	validation_0-rmse:2.24800
# [111]	validation_0-rmse:2.24813
# [112]	validation_0-rmse:2.24848
# [113]	validation_0-rmse:2.24900
# [114]	validation_0-rmse:2.25018
# [115]	validation_0-rmse:2.25087
# [116]	validation_0-rmse:2.25163
# [117]	validation_0-rmse:2.25167
# [118]	validation_0-rmse:2.25160
# [119]	validation_0-rmse:2.25202
# [120]	validation_0-rmse:2.25295
# [121]	validation_0-rmse:2.25318
# [122]	validation_0-rmse:2.25447
# [123]	validation_0-rmse:2.25531
# [124]	validation_0-rmse:2.25594
# [125]	validation_0-rmse:2.25635
# [126]	validation_0-rmse:2.25672
# [127]	validation_0-rmse:2.25795
# [128]	validation_0-rmse:2.25860
# [129]	validation_0-rmse:2.25918
# [130]	validation_0-rmse:2.25975
# [131]	validation_0-rmse:2.26019
# [132]	validation_0-rmse:2.26080
# [133]	validation_0-rmse:2.26078
# [134]	validation_0-rmse:2.26131
# [135]	validation_0-rmse:2.26173
# [136]	validation_0-rmse:2.26234
# [137]	validation_0-rmse:2.26399
# [138]	validation_0-rmse:2.26567
# [139]	validation_0-rmse:2.26641
# [140]	validation_0-rmse:2.26723
# [141]	validation_0-rmse:2.26891
# [142]	validation_0-rmse:2.26935
# [143]	validation_0-rmse:2.26978
# [144]	validation_0-rmse:2.26962
# [145]	validation_0-rmse:2.26998
# [146]	validation_0-rmse:2.26971
# [147]	validation_0-rmse:2.26953
# [148]	validation_0-rmse:2.27017
# [149]	validation_0-rmse:2.27096
# [150]	validation_0-rmse:2.27131
# [151]	validation_0-rmse:2.27153
# [152]	validation_0-rmse:2.27289
# [153]	validation_0-rmse:2.27307
# [154]	validation_0-rmse:2.27383
# [155]	validation_0-rmse:2.27398
# [156]	validation_0-rmse:2.27414
# [157]	validation_0-rmse:2.27435
# [158]	validation_0-rmse:2.27519
# [159]	validation_0-rmse:2.27660
# [160]	validation_0-rmse:2.27672
# [161]	validation_0-rmse:2.27737
# [162]	validation_0-rmse:2.27745
# [163]	validation_0-rmse:2.27725
# [164]	validation_0-rmse:2.27750
# [165]	validation_0-rmse:2.27775
# [166]	validation_0-rmse:2.27776
# [167]	validation_0-rmse:2.27892
# [168]	validation_0-rmse:2.27901
# [169]	validation_0-rmse:2.27928
# [170]	validation_0-rmse:2.27963
# [171]	validation_0-rmse:2.27950
# [172]	validation_0-rmse:2.27982
# [173]	validation_0-rmse:2.28097
# [174]	validation_0-rmse:2.28294
# [175]	validation_0-rmse:2.28293
# [176]	validation_0-rmse:2.28432
# [177]	validation_0-rmse:2.28420
# [178]	validation_0-rmse:2.28444
# [179]	validation_0-rmse:2.28499
# [180]	validation_0-rmse:2.28550
# [181]	validation_0-rmse:2.28589
# [182]	validation_0-rmse:2.28643
# [183]	validation_0-rmse:2.28688
# [184]	validation_0-rmse:2.28705
# [185]	validation_0-rmse:2.28708
# [186]	validation_0-rmse:2.28758
# [187]	validation_0-rmse:2.28804
# [188]	validation_0-rmse:2.28827
# [189]	validation_0-rmse:2.28954
# [190]	validation_0-rmse:2.29104
# [191]	validation_0-rmse:2.29117
# [192]	validation_0-rmse:2.29150
# [193]	validation_0-rmse:2.29303
# [194]	validation_0-rmse:2.29299
# [195]	validation_0-rmse:2.29451
# [196]	validation_0-rmse:2.29505
# [197]	validation_0-rmse:2.29692
# [198]	validation_0-rmse:2.29664
# [199]	validation_0-rmse:2.29717
# [200]	validation_0-rmse:2.29827
# [201]	validation_0-rmse:2.29875
# [202]	validation_0-rmse:2.29912
# [203]	validation_0-rmse:2.29935
# [204]	validation_0-rmse:2.29972
# [205]	validation_0-rmse:2.30007
# [206]	validation_0-rmse:2.30084
# [207]	validation_0-rmse:2.30102
# [208]	validation_0-rmse:2.30290
# [209]	validation_0-rmse:2.30332
# [210]	validation_0-rmse:2.30369
# [211]	validation_0-rmse:2.30426
# [212]	validation_0-rmse:2.30472
# [213]	validation_0-rmse:2.30435
# [214]	validation_0-rmse:2.30464
# [215]	validation_0-rmse:2.30504
# [216]	validation_0-rmse:2.30556
# [217]	validation_0-rmse:2.30640
# [218]	validation_0-rmse:2.30730
# [219]	validation_0-rmse:2.30767
# [220]	validation_0-rmse:2.30724
# [221]	validation_0-rmse:2.30769
# [222]	validation_0-rmse:2.30889
# [223]	validation_0-rmse:2.30922
# [224]	validation_0-rmse:2.30917
# [225]	validation_0-rmse:2.30927
# [226]	validation_0-rmse:2.30981
# [227]	validation_0-rmse:2.30989
# [228]	validation_0-rmse:2.31074
# [229]	validation_0-rmse:2.31184
# [230]	validation_0-rmse:2.31225
# [231]	validation_0-rmse:2.31262
# [232]	validation_0-rmse:2.31295
# [233]	validation_0-rmse:2.31333
# [234]	validation_0-rmse:2.31385
# [235]	validation_0-rmse:2.31379
# [236]	validation_0-rmse:2.31411
# [237]	validation_0-rmse:2.31506
# [238]	validation_0-rmse:2.31534
# [239]	validation_0-rmse:2.31556
# [240]	validation_0-rmse:2.31559
# [241]	validation_0-rmse:2.31656
# [242]	validation_0-rmse:2.31688
# [243]	validation_0-rmse:2.31702
# [244]	validation_0-rmse:2.31758
# [245]	validation_0-rmse:2.31782
# [246]	validation_0-rmse:2.31750
# [247]	validation_0-rmse:2.31791
# [248]	validation_0-rmse:2.31771
# [249]	validation_0-rmse:2.31861

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.3468752555202571
# Mean Absolute Error: 1.6364877067455268
# Mean Squared Error: 5.375963540035936
# Root Mean Squared Error: 2.318612416950262
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Doritos Nacho**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[4]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r6 = XGBRegressor(n_estimators=10, seed=123)
xgb_r5 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r5.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r5.predict(x_test)
# Out:
# [0]	validation_0-rmse:2.38185
# [1]	validation_0-rmse:2.28740
# [2]	validation_0-rmse:2.23465
# [3]	validation_0-rmse:2.20553
# [4]	validation_0-rmse:2.18864
# [5]	validation_0-rmse:2.17644
# [6]	validation_0-rmse:2.16529
# [7]	validation_0-rmse:2.15717
# [8]	validation_0-rmse:2.15440
# [9]	validation_0-rmse:2.15325
# [10]	validation_0-rmse:2.14803
# [11]	validation_0-rmse:2.14558
# [12]	validation_0-rmse:2.14528
# [13]	validation_0-rmse:2.14391
# [14]	validation_0-rmse:2.13974
# [15]	validation_0-rmse:2.14087
# [16]	validation_0-rmse:2.14157
# [17]	validation_0-rmse:2.14131
# [18]	validation_0-rmse:2.14235
# [19]	validation_0-rmse:2.14124
# [20]	validation_0-rmse:2.14165
# [21]	validation_0-rmse:2.14085
# [22]	validation_0-rmse:2.14157
# [23]	validation_0-rmse:2.14083
# [24]	validation_0-rmse:2.14118
# [25]	validation_0-rmse:2.14080
# [26]	validation_0-rmse:2.13837
# [27]	validation_0-rmse:2.13954
# [28]	validation_0-rmse:2.13967
# [29]	validation_0-rmse:2.13979
# [30]	validation_0-rmse:2.13964
# [31]	validation_0-rmse:2.13949
# [32]	validation_0-rmse:2.13995
# [33]	validation_0-rmse:2.14098
# [34]	validation_0-rmse:2.14207
# [35]	validation_0-rmse:2.14275
# [36]	validation_0-rmse:2.14376
# [37]	validation_0-rmse:2.14479
# [38]	validation_0-rmse:2.14514
# [39]	validation_0-rmse:2.14516
# [40]	validation_0-rmse:2.14594
# [41]	validation_0-rmse:2.14742
# [42]	validation_0-rmse:2.14846
# [43]	validation_0-rmse:2.14871
# [44]	validation_0-rmse:2.14928
# [45]	validation_0-rmse:2.15070
# [46]	validation_0-rmse:2.15220
# [47]	validation_0-rmse:2.15242
# [48]	validation_0-rmse:2.15330
# [49]	validation_0-rmse:2.15329
# [50]	validation_0-rmse:2.15323
# [51]	validation_0-rmse:2.15348
# [52]	validation_0-rmse:2.15439
# [53]	validation_0-rmse:2.15417
# [54]	validation_0-rmse:2.15479
# [55]	validation_0-rmse:2.15550
# [56]	validation_0-rmse:2.15608
# [57]	validation_0-rmse:2.15767
# [58]	validation_0-rmse:2.15823
# [59]	validation_0-rmse:2.15866
# [60]	validation_0-rmse:2.15976
# [61]	validation_0-rmse:2.16023
# [62]	validation_0-rmse:2.16159
# [63]	validation_0-rmse:2.16197
# [64]	validation_0-rmse:2.16344
# [65]	validation_0-rmse:2.16369
# [66]	validation_0-rmse:2.16396
# [67]	validation_0-rmse:2.16458
# [68]	validation_0-rmse:2.16487
# [69]	validation_0-rmse:2.16552
# [70]	validation_0-rmse:2.16630
# [71]	validation_0-rmse:2.16737
# [72]	validation_0-rmse:2.16705
# [73]	validation_0-rmse:2.16717
# [74]	validation_0-rmse:2.16782
# [75]	validation_0-rmse:2.16868
# [76]	validation_0-rmse:2.16994
# [77]	validation_0-rmse:2.16916
# [78]	validation_0-rmse:2.16976
# [79]	validation_0-rmse:2.16932
# [80]	validation_0-rmse:2.16986
# [81]	validation_0-rmse:2.17004
# [82]	validation_0-rmse:2.17098
# [83]	validation_0-rmse:2.17287
# [84]	validation_0-rmse:2.17314
# [85]	validation_0-rmse:2.17424
# [86]	validation_0-rmse:2.17483
# [87]	validation_0-rmse:2.17589
# [88]	validation_0-rmse:2.17694
# [89]	validation_0-rmse:2.17817
# [90]	validation_0-rmse:2.17843
# [91]	validation_0-rmse:2.17930
# [92]	validation_0-rmse:2.17941
# [93]	validation_0-rmse:2.18016
# [94]	validation_0-rmse:2.18009
# [95]	validation_0-rmse:2.18082
# [96]	validation_0-rmse:2.18115
# [97]	validation_0-rmse:2.18146
# [98]	validation_0-rmse:2.18242
# [99]	validation_0-rmse:2.18305
# [100]	validation_0-rmse:2.18307
# [101]	validation_0-rmse:2.18341
# [102]	validation_0-rmse:2.18373
# [103]	validation_0-rmse:2.18464
# [104]	validation_0-rmse:2.18527
# [105]	validation_0-rmse:2.18536
# [106]	validation_0-rmse:2.18579
# [107]	validation_0-rmse:2.18750
# [108]	validation_0-rmse:2.18825
# [109]	validation_0-rmse:2.18909
# [110]	validation_0-rmse:2.18908
# [111]	validation_0-rmse:2.19034
# [112]	validation_0-rmse:2.19151
# [113]	validation_0-rmse:2.19242
# [114]	validation_0-rmse:2.19392
# [115]	validation_0-rmse:2.19526
# [116]	validation_0-rmse:2.19653
# [117]	validation_0-rmse:2.19714
# [118]	validation_0-rmse:2.19702
# [119]	validation_0-rmse:2.19795
# [120]	validation_0-rmse:2.19966
# [121]	validation_0-rmse:2.20026
# [122]	validation_0-rmse:2.20053
# [123]	validation_0-rmse:2.20076
# [124]	validation_0-rmse:2.20077
# [125]	validation_0-rmse:2.20099
# [126]	validation_0-rmse:2.20132
# [127]	validation_0-rmse:2.20150
# [128]	validation_0-rmse:2.20168
# [129]	validation_0-rmse:2.20187
# [130]	validation_0-rmse:2.20237
# [131]	validation_0-rmse:2.20279
# [132]	validation_0-rmse:2.20365
# [133]	validation_0-rmse:2.20496
# [134]	validation_0-rmse:2.20495
# [135]	validation_0-rmse:2.20540
# [136]	validation_0-rmse:2.20550
# [137]	validation_0-rmse:2.20619
# [138]	validation_0-rmse:2.20604
# [139]	validation_0-rmse:2.20604
# [140]	validation_0-rmse:2.20640
# [141]	validation_0-rmse:2.20696
# [142]	validation_0-rmse:2.20690
# [143]	validation_0-rmse:2.20716
# [144]	validation_0-rmse:2.20773
# [145]	validation_0-rmse:2.20850
# [146]	validation_0-rmse:2.20886
# [147]	validation_0-rmse:2.20967
# [148]	validation_0-rmse:2.21084
# [149]	validation_0-rmse:2.21305
# [150]	validation_0-rmse:2.21470
# [151]	validation_0-rmse:2.21557
# [152]	validation_0-rmse:2.21630
# [153]	validation_0-rmse:2.21637
# [154]	validation_0-rmse:2.21680
# [155]	validation_0-rmse:2.21811
# [156]	validation_0-rmse:2.21820
# [157]	validation_0-rmse:2.21896
# [158]	validation_0-rmse:2.22050
# [159]	validation_0-rmse:2.22072
# [160]	validation_0-rmse:2.22146
# [161]	validation_0-rmse:2.22182
# [162]	validation_0-rmse:2.22176
# [163]	validation_0-rmse:2.22181
# [164]	validation_0-rmse:2.22281
# [165]	validation_0-rmse:2.22300
# [166]	validation_0-rmse:2.22406
# [167]	validation_0-rmse:2.22441
# [168]	validation_0-rmse:2.22592
# [169]	validation_0-rmse:2.22689
# [170]	validation_0-rmse:2.22819
# [171]	validation_0-rmse:2.22826
# [172]	validation_0-rmse:2.22904
# [173]	validation_0-rmse:2.22930
# [174]	validation_0-rmse:2.22977
# [175]	validation_0-rmse:2.22922
# [176]	validation_0-rmse:2.22944
# [177]	validation_0-rmse:2.22981
# [178]	validation_0-rmse:2.23051
# [179]	validation_0-rmse:2.23110
# [180]	validation_0-rmse:2.23125
# [181]	validation_0-rmse:2.23132
# [182]	validation_0-rmse:2.23167
# [183]	validation_0-rmse:2.23165
# [184]	validation_0-rmse:2.23173
# [185]	validation_0-rmse:2.23287
# [186]	validation_0-rmse:2.23368
# [187]	validation_0-rmse:2.23478
# [188]	validation_0-rmse:2.23469
# [189]	validation_0-rmse:2.23596
# [190]	validation_0-rmse:2.23629
# [191]	validation_0-rmse:2.23680
# [192]	validation_0-rmse:2.23728
# [193]	validation_0-rmse:2.23777
# [194]	validation_0-rmse:2.23799
# [195]	validation_0-rmse:2.23790
# [196]	validation_0-rmse:2.23825
# [197]	validation_0-rmse:2.23826
# [198]	validation_0-rmse:2.23880
# [199]	validation_0-rmse:2.23973
# [200]	validation_0-rmse:2.23965
# [201]	validation_0-rmse:2.23962
# [202]	validation_0-rmse:2.24012
# [203]	validation_0-rmse:2.24054
# [204]	validation_0-rmse:2.24080
# [205]	validation_0-rmse:2.24167
# [206]	validation_0-rmse:2.24216
# [207]	validation_0-rmse:2.24258
# [208]	validation_0-rmse:2.24254
# [209]	validation_0-rmse:2.24315
# [210]	validation_0-rmse:2.24441
# [211]	validation_0-rmse:2.24518
# [212]	validation_0-rmse:2.24481
# [213]	validation_0-rmse:2.24510
# [214]	validation_0-rmse:2.24606
# [215]	validation_0-rmse:2.24629
# [216]	validation_0-rmse:2.24729
# [217]	validation_0-rmse:2.24803
# [218]	validation_0-rmse:2.24855
# [219]	validation_0-rmse:2.24891
# [220]	validation_0-rmse:2.24985
# [221]	validation_0-rmse:2.25102
# [222]	validation_0-rmse:2.25169
# [223]	validation_0-rmse:2.25305
# [224]	validation_0-rmse:2.25395
# [225]	validation_0-rmse:2.25478
# [226]	validation_0-rmse:2.25559
# [227]	validation_0-rmse:2.25599
# [228]	validation_0-rmse:2.25647
# [229]	validation_0-rmse:2.25695
# [230]	validation_0-rmse:2.25698
# [231]	validation_0-rmse:2.25723
# [232]	validation_0-rmse:2.25800
# [233]	validation_0-rmse:2.25821
# [234]	validation_0-rmse:2.25858
# [235]	validation_0-rmse:2.25864
# [236]	validation_0-rmse:2.25945
# [237]	validation_0-rmse:2.25909
# [238]	validation_0-rmse:2.25911
# [239]	validation_0-rmse:2.25951
# [240]	validation_0-rmse:2.25988
# [241]	validation_0-rmse:2.26004
# [242]	validation_0-rmse:2.26023
# [243]	validation_0-rmse:2.26037
# [244]	validation_0-rmse:2.26020
# [245]	validation_0-rmse:2.25993
# [246]	validation_0-rmse:2.26045
# [247]	validation_0-rmse:2.26140
# [248]	validation_0-rmse:2.26196
# [249]	validation_0-rmse:2.26275

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.2696174940641838
# Mean Absolute Error: 1.5986242804714084
# Mean Squared Error: 5.120051293919524
# Root Mean Squared Error: 2.262753034230542
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Panini Original**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[5]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r7 = XGBRegressor(n_estimators=10, seed=123)
xgb_r6 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r6.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r6.predict(x_test)
# Out:
# [0]	validation_0-rmse:1.87736
# [241]	validation_0-rmse:1.81343
# [242]	validation_0-rmse:1.81425
# [243]	validation_0-rmse:1.81426
# [244]	validation_0-rmse:1.81512
# [245]	validation_0-rmse:1.81521
# [246]	validation_0-rmse:1.81543
# [247]	validation_0-rmse:1.81542
# [248]	validation_0-rmse:1.81541
# [249]	validation_0-rmse:1.81585

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.24042592172159072
# Mean Absolute Error: 1.3151072898881557
# Mean Squared Error: 3.2973229894701706
# Root Mean Squared Error: 1.8158532400692988
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Fritos Limon y Sal**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[6]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r8 = XGBRegressor(n_estimators=10, seed=123)
xgb_r7 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r7.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r7.predict(x_test)
# Out:
# [0]	validation_0-rmse:1.95380
# [1]	validation_0-rmse:1.87954
# [2]	validation_0-rmse:1.84686
# [3]	validation_0-rmse:1.83500
# [4]	validation_0-rmse:1.82512
# [5]	validation_0-rmse:1.81856
# [6]	validation_0-rmse:1.81435
# [7]	validation_0-rmse:1.81261
# [8]	validation_0-rmse:1.81277
# [9]	validation_0-rmse:1.81104
# [10]	validation_0-rmse:1.80985
# [11]	validation_0-rmse:1.80858
# [12]	validation_0-rmse:1.80794
# [13]	validation_0-rmse:1.80979
# [14]	validation_0-rmse:1.80933
# [15]	validation_0-rmse:1.80889
# [16]	validation_0-rmse:1.80999
# [17]	validation_0-rmse:1.80841
# [18]	validation_0-rmse:1.80874
# [19]	validation_0-rmse:1.80938
# [20]	validation_0-rmse:1.81002
# [21]	validation_0-rmse:1.81158
# [22]	validation_0-rmse:1.81201
# [23]	validation_0-rmse:1.81304
# [24]	validation_0-rmse:1.81249
# [25]	validation_0-rmse:1.81204
# [26]	validation_0-rmse:1.81126
# [27]	validation_0-rmse:1.81152
# [28]	validation_0-rmse:1.81242
# [29]	validation_0-rmse:1.81273
# [30]	validation_0-rmse:1.81313
# [31]	validation_0-rmse:1.81427
# [32]	validation_0-rmse:1.81508
# [33]	validation_0-rmse:1.81542
# [34]	validation_0-rmse:1.81549
# [35]	validation_0-rmse:1.81566
# [36]	validation_0-rmse:1.81581
# [37]	validation_0-rmse:1.81654
# [38]	validation_0-rmse:1.81804
# [39]	validation_0-rmse:1.82012
# [40]	validation_0-rmse:1.82058
# [41]	validation_0-rmse:1.82057
# [42]	validation_0-rmse:1.82070
# [43]	validation_0-rmse:1.82028
# [44]	validation_0-rmse:1.82114
# [45]	validation_0-rmse:1.82175
# [46]	validation_0-rmse:1.82334
# [207]	validation_0-rmse:1.91081
# [208]	validation_0-rmse:1.91141
# [209]	validation_0-rmse:1.91204
# [210]	validation_0-rmse:1.91225
# [211]	validation_0-rmse:1.91290
# [212]	validation_0-rmse:1.91364
# [213]	validation_0-rmse:1.91408
# [214]	validation_0-rmse:1.91510
# [215]	validation_0-rmse:1.91560
# [216]	validation_0-rmse:1.91634
# [217]	validation_0-rmse:1.91722
# [218]	validation_0-rmse:1.91757
# [219]	validation_0-rmse:1.91762
# [220]	validation_0-rmse:1.91743
# [221]	validation_0-rmse:1.91811
# [222]	validation_0-rmse:1.91942
# [223]	validation_0-rmse:1.91930
# [224]	validation_0-rmse:1.91943
# [225]	validation_0-rmse:1.92020
# [226]	validation_0-rmse:1.92054
# [227]	validation_0-rmse:1.92109
# [228]	validation_0-rmse:1.92135
# [229]	validation_0-rmse:1.92141
# [230]	validation_0-rmse:1.92184
# [231]	validation_0-rmse:1.92216
# [232]	validation_0-rmse:1.92310
# [233]	validation_0-rmse:1.92327
# [234]	validation_0-rmse:1.92263
# [235]	validation_0-rmse:1.92399
# [236]	validation_0-rmse:1.92451
# [237]	validation_0-rmse:1.92513
# [238]	validation_0-rmse:1.92503
# [239]	validation_0-rmse:1.92497
# [240]	validation_0-rmse:1.92552
# [241]	validation_0-rmse:1.92675
# [242]	validation_0-rmse:1.92739
# [243]	validation_0-rmse:1.92786
# [244]	validation_0-rmse:1.92787
# [245]	validation_0-rmse:1.92784
# [246]	validation_0-rmse:1.92858
# [247]	validation_0-rmse:1.92963
# [248]	validation_0-rmse:1.93001
# [249]	validation_0-rmse:1.93102

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.17595326188981086
# Mean Absolute Error: 1.3605246169979748
# Mean Squared Error: 3.7288391223934902
# Root Mean Squared Error: 1.9310202283750137
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Sabritas Flamin Hot**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[7]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r9 = XGBRegressor(n_estimators=10, seed=123)
xgb_r8 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r8.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r8.predict(x_test)
# Out:
# [0]	validation_0-rmse:1.97328
# [1]	validation_0-rmse:1.90007
# [2]	validation_0-rmse:1.85671
# [3]	validation_0-rmse:1.82693
# [4]	validation_0-rmse:1.81367
# [5]	validation_0-rmse:1.79999
# [6]	validation_0-rmse:1.79272
# [7]	validation_0-rmse:1.78938
# [8]	validation_0-rmse:1.78763
# [9]	validation_0-rmse:1.78743
# [10]	validation_0-rmse:1.78649
# [11]	validation_0-rmse:1.78653
# [12]	validation_0-rmse:1.78330
# [13]	validation_0-rmse:1.78178
rics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.21887666898772495
# Mean Absolute Error: 1.3324718879996902
# Mean Squared Error: 3.628609556047475
# Root Mean Squared Error: 1.9048909564716494
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Sprite**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[8]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r10 = XGBRegressor(n_estimators=10, seed=123)
xgb_r9 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r9.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r9.predict(x_test)
# Out:
# [0]	validation_0-rmse:1.61823
# [1]	validation_0-rmse:1.55892
# [2]	validation_0-rmse:1.53629
# [3]	validation_0-rmse:1.52659
# [4]	validation_0-rmse:1.51945
# [5]	validation_0-rmse:1.51438
# [6]	validation_0-rmse:1.51335
# [7]	validation_0-rmse:1.51249
# [8]	validation_0-rmse:1.51103
# [9]	validation_0-rmse:1.51037
# [10]	validation_0-rmse:1.50994
# [11]	validation_0-rmse:1.51025
# [12]	validation_0-rmse:1.50996
# [13]	validation_0-rmse:1.51012
# [14]	validation_0-rmse:1.50977
# [15]	validation_0-rmse:1.50961
# [16]	validation_0-rmse:1.50946
# [17]	validation_0-rmse:1.50853
# [18]	validation_0-rmse:1.50884
# [19]	validation_0-rmse:1.50960
# [20]	validation_0-rmse:1.51069
# [21]	validation_0-rmse:1.51060
# [22]	validation_0-rmse:1.51069
# [23]	validation_0-rmse:1.51115
# [24]	validation_0-rmse:1.51136
# [25]	validation_0-rmse:1.51192
# [26]	validation_0-rmse:1.51292
# [27]	validation_0-rmse:1.51336
# [28]	validation_0-rmse:1.51334
# [29]	validation_0-rmse:1.51317
# [30]	validation_0-rmse:1.51430
# [31]	validation_0-rmse:1.51620
# [32]	validation_0-rmse:1.51573
# [33]	validation_0-rmse:1.51693
# [34]	validation_0-rmse:1.51931
# [35]	validation_0-rmse:1.52179
# [36]	validation_0-rmse:1.52277
# [37]	validation_0-rmse:1.52568
# [38]	validation_0-rmse:1.52712
# [39]	validation_0-rmse:1.52754
# [40]	validation_0-rmse:1.52699
# [41]	validation_0-rmse:1.52667
# [42]	validation_0-rmse:1.52642
# [43]	validation_0-rmse:1.52650
# [44]	validation_0-rmse:1.52691
# [45]	validation_0-rmse:1.52912
# [46]	validation_0-rmse:1.52929
# [47]	validation_0-rmse:1.52989
# [48]	validation_0-rmse:1.53018
# [49]	validation_0-rmse:1.53109
# [50]	validation_0-rmse:1.53177
# [51]	validation_0-rmse:1.53189
# [52]	validation_0-rmse:1.53183
# [53]	validation_0-rmse:1.53293
# [54]	validation_0-rmse:1.53371
# [55]	validation_0-rmse:1.53488
# [56]	validation_0-rmse:1.53487
# [57]	validation_0-rmse:1.53551
# [58]	validation_0-rmse:1.53611
# [59]	validation_0-rmse:1.53670
# [60]	validation_0-rmse:1.53920
# [221]	validation_0-rmse:1.61320
# [222]	validation_0-rmse:1.61397
# [223]	validation_0-rmse:1.61395
# [224]	validation_0-rmse:1.61411
# [225]	validation_0-rmse:1.61411
# [226]	validation_0-rmse:1.61466
# [227]	validation_0-rmse:1.61502
# [228]	validation_0-rmse:1.61502
# [229]	validation_0-rmse:1.61536
# [230]	validation_0-rmse:1.61609
# [231]	validation_0-rmse:1.61622
# [232]	validation_0-rmse:1.61710
# [233]	validation_0-rmse:1.61732
# [234]	validation_0-rmse:1.61727
# [235]	validation_0-rmse:1.61727
# [236]	validation_0-rmse:1.61770
# [237]	validation_0-rmse:1.61831
# [238]	validation_0-rmse:1.61820
# [239]	validation_0-rmse:1.61823
# [240]	validation_0-rmse:1.61913
# [241]	validation_0-rmse:1.61953
# [242]	validation_0-rmse:1.61988
# [243]	validation_0-rmse:1.61999
# [244]	validation_0-rmse:1.62038
# [245]	validation_0-rmse:1.62105
# [246]	validation_0-rmse:1.62120
# [247]	validation_0-rmse:1.62166
# [248]	validation_0-rmse:1.62178
# [249]	validation_0-rmse:1.62159

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.1458556586776849
# Mean Absolute Error: 1.1675276020336685
# Mean Squared Error: 2.6295457662892248
# Root Mean Squared Error: 1.6215874217226849
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Cheetos**

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == top10[8]]
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r10 = XGBRegressor(n_estimators=10, seed=123)
xgb_r10 = XGBRegressor(learning_rate=0.5, n_estimators=250)
xgb_r10.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r10.predict(x_test)
# Out:
# [0]	validation_0-rmse:1.61823
# [1]	validation_0-rmse:1.55892
# [2]	validation_0-rmse:1.53629
# [3]	validation_0-rmse:1.52659
# [4]	validation_0-rmse:1.51945
# [5]	validation_0-rmse:1.51438
# [6]	validation_0-rmse:1.51335
# [7]	validation_0-rmse:1.51249
# [8]	validation_0-rmse:1.51103
# [9]	validation_0-rmse:1.51037
# [10]	validation_0-rmse:1.50994
# [11]	validation_0-rmse:1.51025
# [12]	validation_0-rmse:1.50996
# [13]	validation_0-rmse:1.51012
# [14]	validation_0-rmse:1.50977
# [15]	validation_0-rmse:1.50961
# [16]	validation_0-rmse:1.50946
# [17]	validation_0-rmse:1.50853
# [18]	validation_0-rmse:1.50884
# [19]	validation_0-rmse:1.50960
# [20]	validation_0-rmse:1.51069
# [21]	validation_0-rmse:1.51060
# [22]	validation_0-rmse:1.51069
# [23]	validation_0-rmse:1.51115
# [24]	validation_0-rmse:1.51136
# [25]	validation_0-rmse:1.51192
# [26]	validation_0-rmse:1.51292
# [27]	validation_0-rmse:1.51336
# [188]	validation_0-rmse:1.60139
# [189]	validation_0-rmse:1.60228
# [190]	validation_0-rmse:1.60263
# [191]	validation_0-rmse:1.60335
# [192]	validation_0-rmse:1.60420
# [193]	validation_0-rmse:1.60448
# [194]	validation_0-rmse:1.60474
# [195]	validation_0-rmse:1.60524
# [196]	validation_0-rmse:1.60559
# [197]	validation_0-rmse:1.60661
# [198]	validation_0-rmse:1.60699
# [199]	validation_0-rmse:1.60778
# [200]	validation_0-rmse:1.60789
# [201]	validation_0-rmse:1.60840
# [202]	validation_0-rmse:1.60867
# [203]	validation_0-rmse:1.60910
# [204]	validation_0-rmse:1.60932
# [205]	validation_0-rmse:1.61014
# [206]	validation_0-rmse:1.61121
# [207]	validation_0-rmse:1.61124
# [208]	validation_0-rmse:1.61091
# [209]	validation_0-rmse:1.61111
# [210]	validation_0-rmse:1.61117
# [211]	validation_0-rmse:1.61140
# [212]	validation_0-rmse:1.61143
# [213]	validation_0-rmse:1.61200
# [214]	validation_0-rmse:1.61190
# [215]	validation_0-rmse:1.61177
# [216]	validation_0-rmse:1.61222
# [217]	validation_0-rmse:1.61248
# [218]	validation_0-rmse:1.61258
# [219]	validation_0-rmse:1.61274
# [220]	validation_0-rmse:1.61294
# [221]	validation_0-rmse:1.61320
# [222]	validation_0-rmse:1.61397
# [223]	validation_0-rmse:1.61395
# [224]	validation_0-rmse:1.61411
# [225]	validation_0-rmse:1.61411
# [226]	validation_0-rmse:1.61466
# [227]	validation_0-rmse:1.61502
# [228]	validation_0-rmse:1.61502
# [229]	validation_0-rmse:1.61536
# [230]	validation_0-rmse:1.61609
# [231]	validation_0-rmse:1.61622
# [232]	validation_0-rmse:1.61710
# [233]	validation_0-rmse:1.61732
# [234]	validation_0-rmse:1.61727
# [235]	validation_0-rmse:1.61727
# [236]	validation_0-rmse:1.61770
# [237]	validation_0-rmse:1.61831
# [238]	validation_0-rmse:1.61820
# [239]	validation_0-rmse:1.61823
# [240]	validation_0-rmse:1.61913
# [241]	validation_0-rmse:1.61953
# [242]	validation_0-rmse:1.61988
# [243]	validation_0-rmse:1.61999
# [244]	validation_0-rmse:1.62038
# [245]	validation_0-rmse:1.62105
# [246]	validation_0-rmse:1.62120
# [247]	validation_0-rmse:1.62166
# [248]	validation_0-rmse:1.62178
# [249]	validation_0-rmse:1.62159

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.1458556586776849
# Mean Absolute Error: 1.1675276020336685
# Mean Squared Error: 2.6295457662892248
# Root Mean Squared Error: 1.6215874217226849
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
# import pickle

# # Supongamos que tienes una lista de nombres de modelos
# nombres_modelos = [
#     "ModeloVentas",
#     "ModeloCoca",
#     "ModeloAgua",
#     "ModeloSabritas",
#     "ModeloRuffles",
#     "ModeloDoritos",
#     "ModeloPanini",
#     "ModeloFritos",
#     "ModeloFlamin",
#     "ModeloSprite",
#     "ModeloCheetos",
# ]

# # Supongamos también que tienes una lista de modelos ya entrenados
# modelos_entrenados = [
#     xgb_r,
#     xgb_r1,
#     xgb_r2,
#     xgb_r3,
#     xgb_r4,
#     xgb_r5,
#     xgb_r6,
#     xgb_r7,
#     xgb_r8,
#     xgb_r9,
#     xgb_r10,
# ]

# # Guardar cada modelo en un archivo pickle con su nombre correspondiente
# for nombre, modelo in zip(nombres_modelos, modelos_entrenados):
#     with open(f"{nombre}.pkl", "wb") as archivo:
#         pickle.dump(modelo, archivo)

# %%
# import pickle

# for i in range(93, 98):
#     modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == i]
#     X = modelo2.drop(columns=["Quantity"])
#     y = modelo2["Quantity"]
#     x_train, x_test, y_train, y_test = train_test_split(
#         X,
#         y,
#         test_size=0.3,
#         random_state=0,
#     )

#     eval_set = [(x_test, y_test)]

#     train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
#     test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

#     xgb_r = XGBRegressor(learning_rate=0.5, n_estimators=250)
#     xgb_r.fit(x_train, y_train, eval_set=eval_set, verbose=True)
#     y_pred = xgb_r.predict(x_test)

#     # Evaluamos el modelo
#     print("R2 Score:", metrics.r2_score(y_test, y_pred))
#     print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
#     print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
#     print(
#         "Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred))
#     )

#     with open(f"Modelo{i}.pkl", "wb") as archivo:
#         pickle.dump(xgb_r, archivo)

# %%
# Faltan 88 y 92
# Out:
# Empty DataFrame
# Columns: [ProductName, Quantity, Capacity, Passengers, Bookings, Semana, Mes, Duracion, Hora, Dia, destino_amigosfamilia, destino_ciudadfronteriza, destino_ciudadprincipal, destino_ecoturismo, destino_playa, origen_amigosfamilia, origen_ciudadfronteriza, origen_ciudadprincipal, origen_ecoturismo, origen_playa, Book_Pass, departure_AB, departure_AD, departure_AE, departure_AF, departure_AI, departure_AJ, departure_AK, departure_AL, departure_AM, departure_AO, departure_AP, departure_AQ, departure_AR, departure_AS, departure_AT, departure_AU, departure_AV, departure_AW, departure_AX, departure_AY, departure_AZ, departure_BA, departure_BB, departure_BC, departure_BD, departure_BE, departure_BF, departure_BG, departure_BH, departure_BJ, departure_BK, departure_BL, departure_BM, departure_BN, departure_BO, departure_BP, departure_BQ, departure_BS, departure_BT, arrival_AB, arrival_AD, arrival_AE, arrival_AF, arrival_AI, arrival_AJ, arrival_AK, arrival_AL, arrival_AM, arrival_AO, arrival_AP, arrival_AQ, arrival_AR, arrival_AT, arrival_AU, arrival_AV, arrival_AW, arrival_AX, arrival_AY, arrival_AZ, arrival_BA, arrival_BB, arrival_BC, arrival_BD, arrival_BE, arrival_BF, arrival_BG, arrival_BH, arrival_BJ, arrival_BK, arrival_BL, arrival_BM, arrival_BN, arrival_BO, arrival_BP, arrival_BQ, arrival_BS, arrival_BT]
# Index: []
#
# [0 rows x 98 columns]
