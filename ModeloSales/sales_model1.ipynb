# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
import xgboost as xg
from xgboost import XGBRegressor


def one_hot_encode(
    df: pd.DataFrame,
    column: str,
    prefix: str,
) -> pd.DataFrame:

    df_ = df.copy()
    df_encoded = pd.get_dummies(df_[column], dtype="int")
    for col in df_encoded:
        df_[f"{prefix}_{col}"] = df_encoded[col]

    return df_.drop(columns=[column])

# %%
vuelos = pd.read_parquet("../resources/flights_clean.parquet")
ventas = pd.read_parquet("../resources/sales_clean.parquet")

# %%
# Merge a ambos dataframes
vuelos_ventas = pd.merge(ventas, vuelos, on="Flight_ID")
vuelos_ventas.drop(columns=["index", "Aeronave"], inplace=True)
vuelos_ventas
# Out:
#                                 Flight_ID  ProductType  \
# 0        a05290288259526edd3601160b10e1de      Botanas
# 1        a05290288259526edd3601160b10e1de      Botanas
# 2        a05290288259526edd3601160b10e1de      Botanas
# 3        a05290288259526edd3601160b10e1de    Refrescos
# 4        a05290288259526edd3601160b10e1de      Licores
# ...                                   ...          ...
# 2095947  6113fc0448cd548cd7e7d3f76e7872c5  Perecederos
# 2095948  78b84bc241b924d6c89e171a34b0f60c  Perecederos
# 2095949  2d7d30a16334ee2db84e5bc027a4a186      Licores
# 2095950  7a56b895719a91ca6a98004cff956b7d      Licores
# 2095951  6a73f28314810ec3033e399c2b69f99d      Licores
#
#                        ProductName  Quantity  TotalSales DepartureStation  \
# 0              Carne Seca Habanero         1        55.0               AW
# 1                          Cheetos         2        98.0               AW
# 2                    Ruffles Queso         6       294.0               AW
# 3                  Coca Sin Azucar         2        96.0               AW
# 4                    Jack And Coke         1        72.0               AW
# ...                            ...       ...         ...              ...
# 2095947     Cuerno Clasico De Pavo         5       575.0               AF
# 2095948     Cuerno Clasico De Pavo         1       115.0               AT
# 2095949  Vino Tinto Sangre De Toro         1       155.0               AO
# 2095950  Vino Tinto Sangre De Toro         1       155.0               AL
# 2095951  Vino Tinto Sangre De Toro         1       155.0               BQ
#
#         ArrivalStation     Destination_Type          Origin_Type  \
# 0                   AO     Ciudad Principal     Ciudad Principal
# 1                   AO     Ciudad Principal     Ciudad Principal
# 2                   AO     Ciudad Principal     Ciudad Principal
# 3                   AO     Ciudad Principal     Ciudad Principal
# 4                   AO     Ciudad Principal     Ciudad Principal
# ...                ...                  ...                  ...
# 2095947             AW     Ciudad Principal    Ciudad Fronteriza
# 2095948             BP  MX Amigos y Familia     Ciudad Principal
# 2095949             BD                Playa     Ciudad Principal
# 2095950             AW     Ciudad Principal  MX Amigos y Familia
# 2095951             AU           Ecoturismo  MX Amigos y Familia
#
#                         STD                 STA  Capacity  Passengers  \
# 0       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 1       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 2       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 3       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# 4       2023-08-28 19:20:00 2023-08-28 20:45:00       186       131.0
# ...                     ...                 ...       ...         ...
# 2095947 2023-11-02 23:10:00 2023-11-03 00:50:00       240       154.0
# 2095948 2023-10-05 06:00:00 2023-10-05 07:05:00       240       188.0
# 2095949 2023-05-16 18:45:00 2023-05-16 19:35:00       180       149.0
# 2095950 2023-02-15 07:00:00 2023-02-15 08:25:00       220       210.0
# 2095951 2023-05-05 17:50:00 2023-05-05 18:55:00       220       211.0
#
#          Bookings  Semana  Mes
# 0           100.0      35    8
# 1           100.0      35    8
# 2           100.0      35    8
# 3           100.0      35    8
# 4           100.0      35    8
# ...           ...     ...  ...
# 2095947     119.0      44   11
# 2095948     150.0      40   10
# 2095949     112.0      20    5
# 2095950     170.0       7    2
# 2095951     169.0      18    5
#
# [2095952 rows x 16 columns]

# %%
vuelos_ventas = vuelos_ventas.groupby("Flight_ID").agg(
    {
        "TotalSales": "sum",
        "Bookings": "mean",
        "Passengers": "mean",
        "Origin_Type": "first",
        "Destination_Type": "first",
        "STD": "first",
        "STA": "first",
        "DepartureStation": "first",
        "ArrivalStation": "first",
        "Semana": "first",
        "Mes": "first",
        "Capacity": "first",
    }
)
vuelos_ventas["STD"] = pd.to_datetime(vuelos_ventas["STD"])

vuelos_ventas["STA"] = pd.to_datetime(vuelos_ventas["STA"])

vuelos_ventas["Duracion"] = vuelos_ventas["STA"] - vuelos_ventas["STD"]

vuelos_ventas["Duracion"] = vuelos_ventas["Duracion"].dt.total_seconds() / 60

vuelos_ventas["Hora"] = vuelos_ventas["STD"].dt.hour

vuelos_ventas["Dia"] = vuelos_ventas["STD"].dt.day

# Cambiar tipos de destinos a one-hot encoding

destination_type = vuelos_ventas["Destination_Type"].map(

    {

        "Ciudad Principal": "destino_ciudadprincipal",

        "Playa": "destino_playa",

        "MX Amigos y Familia": "destino_amigosfamilia",

        "Ciudad Fronteriza": "destino_ciudadfronteriza",

        "Ecoturismo": "destino_ecoturismo",

    }

)

destination_type = pd.get_dummies(destination_type, dtype="int")

vuelos_ventas = (

    pd.concat([vuelos_ventas, destination_type], axis=1)

    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas

)

vuelos_ventas = (

    vuelos_ventas.drop(columns=["Destination_Type"])

    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas

)

origen_type = vuelos_ventas["Origin_Type"].map(

    {

        "Ciudad Principal": "origen_ciudadprincipal",

        "Playa": "origen_playa",

        "MX Amigos y Familia": "origen_amigosfamilia",

        "Ciudad Fronteriza": "origen_ciudadfronteriza",

        "Ecoturismo": "origen_ecoturismo",

    }

)

origen_type = pd.get_dummies(origen_type, dtype="int")

vuelos_ventas = (

    pd.concat([vuelos_ventas, origen_type], axis=1)

    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas

)

vuelos_ventas = (

    vuelos_ventas.drop(columns=["Origin_Type"])
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas

)

vuelos_ventas["Book_Pass"] = vuelos_ventas["Bookings"] / vuelos_ventas["Passengers"]

vuelos_ventas.drop(columns=["STD", "STA"], inplace=True)

vuelos_ventas = one_hot_encode(vuelos_ventas, "DepartureStation", "departure")

vuelos_ventas = one_hot_encode(vuelos_ventas, "ArrivalStation", "arrival")

# %%
# Hacemos el modelo de regesion
X = vuelos_ventas.drop(columns=["TotalSales"])
y = vuelos_ventas["TotalSales"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r = XGBRegressor(n_estimators=10, seed=123)
xgb_r = XGBRegressor(learning_rate=0.3, n_estimators=250)
xgb_r.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r.predict(x_test)
# Out:
# [0]	validation_0-rmse:2481.74894
# [1]	validation_0-rmse:2198.97013
# [2]	validation_0-rmse:2033.32798
# [3]	validation_0-rmse:1907.75976
# [4]	validation_0-rmse:1834.64862
# [5]	validation_0-rmse:1773.85720
# [6]	validation_0-rmse:1717.03975
# [7]	validation_0-rmse:1690.80258
# [8]	validation_0-rmse:1672.18555
# [9]	validation_0-rmse:1654.92034
# [10]	validation_0-rmse:1639.77394
# [11]	validation_0-rmse:1630.80127
# [12]	validation_0-rmse:1618.72050
# [13]	validation_0-rmse:1610.92381
# [14]	validation_0-rmse:1605.80254
# [15]	validation_0-rmse:1602.88202
# [16]	validation_0-rmse:1596.54765
# [17]	validation_0-rmse:1590.12355
# [18]	validation_0-rmse:1583.64605
# [19]	validation_0-rmse:1581.56075
# [20]	validation_0-rmse:1579.30407
# [21]	validation_0-rmse:1577.54724
# [22]	validation_0-rmse:1576.87235
# [23]	validation_0-rmse:1571.83939
# [24]	validation_0-rmse:1567.25605
# [25]	validation_0-rmse:1565.76184
# [26]	validation_0-rmse:1564.85253
# [27]	validation_0-rmse:1562.18313
# [28]	validation_0-rmse:1561.84044
# [29]	validation_0-rmse:1560.16143
# [30]	validation_0-rmse:1559.18387
# [31]	validation_0-rmse:1549.17618
# [32]	validation_0-rmse:1548.72418
# [33]	validation_0-rmse:1548.22617
# [34]	validation_0-rmse:1546.02571
# [35]	validation_0-rmse:1544.19914
# [36]	validation_0-rmse:1543.72081
# [37]	validation_0-rmse:1542.38389
# [38]	validation_0-rmse:1541.60536
# [39]	validation_0-rmse:1541.55651
# [40]	validation_0-rmse:1541.28974
# [41]	validation_0-rmse:1540.73842
# [42]	validation_0-rmse:1541.02348
# [43]	validation_0-rmse:1540.25910
# [44]	validation_0-rmse:1539.42640
# [45]	validation_0-rmse:1539.00081
# [46]	validation_0-rmse:1537.79977
# [47]	validation_0-rmse:1537.97370
# [48]	validation_0-rmse:1537.26309
# [49]	validation_0-rmse:1536.89051
# [50]	validation_0-rmse:1536.44413
# [51]	validation_0-rmse:1536.00321
# [52]	validation_0-rmse:1535.86007
# [53]	validation_0-rmse:1535.67142
# [54]	validation_0-rmse:1535.39971
# [55]	validation_0-rmse:1535.17596
# [56]	validation_0-rmse:1535.33426
# [57]	validation_0-rmse:1534.98909
# [58]	validation_0-rmse:1534.53405
# [59]	validation_0-rmse:1534.33472
# [60]	validation_0-rmse:1532.54727
# [61]	validation_0-rmse:1531.99691
# [62]	validation_0-rmse:1531.14716
# [63]	validation_0-rmse:1530.78608
# [64]	validation_0-rmse:1531.08354
# [65]	validation_0-rmse:1530.37308
# [66]	validation_0-rmse:1530.24552
# [67]	validation_0-rmse:1530.00950
# [68]	validation_0-rmse:1529.94531
# [69]	validation_0-rmse:1529.91451
# [70]	validation_0-rmse:1530.12711
# [71]	validation_0-rmse:1529.35344
# [72]	validation_0-rmse:1529.44208
# [73]	validation_0-rmse:1529.37262
# [74]	validation_0-rmse:1529.26712
# [75]	validation_0-rmse:1529.47833
# [76]	validation_0-rmse:1529.30044
# [77]	validation_0-rmse:1529.36469
# [78]	validation_0-rmse:1531.14660
# [79]	validation_0-rmse:1530.50590
# [80]	validation_0-rmse:1530.47133
# [81]	validation_0-rmse:1530.03560
# [82]	validation_0-rmse:1529.02264
# [83]	validation_0-rmse:1529.03809
# [84]	validation_0-rmse:1529.74458
# [85]	validation_0-rmse:1529.20036
# [86]	validation_0-rmse:1529.12424
# [87]	validation_0-rmse:1529.47101
# [88]	validation_0-rmse:1529.32480
# [89]	validation_0-rmse:1529.40003
# [90]	validation_0-rmse:1529.32436
# [91]	validation_0-rmse:1529.28702
# [92]	validation_0-rmse:1528.84643
# [93]	validation_0-rmse:1528.28817
# [94]	validation_0-rmse:1528.34431
# [95]	validation_0-rmse:1528.26917
# [96]	validation_0-rmse:1528.31492
# [97]	validation_0-rmse:1528.24486
# [98]	validation_0-rmse:1527.91040
# [99]	validation_0-rmse:1527.56960
# [100]	validation_0-rmse:1527.34459
# [101]	validation_0-rmse:1527.52757
# [102]	validation_0-rmse:1527.30644
# [103]	validation_0-rmse:1527.87421
# [104]	validation_0-rmse:1527.64052
# [105]	validation_0-rmse:1527.43930
# [106]	validation_0-rmse:1527.73283
# [107]	validation_0-rmse:1527.77894
# [108]	validation_0-rmse:1527.29665
# [109]	validation_0-rmse:1525.36377
# [110]	validation_0-rmse:1525.37465
# [111]	validation_0-rmse:1525.87651
# [112]	validation_0-rmse:1526.05718
# [113]	validation_0-rmse:1525.89653
# [114]	validation_0-rmse:1526.18507
# [115]	validation_0-rmse:1526.18414
# [116]	validation_0-rmse:1526.27842
# [117]	validation_0-rmse:1526.23329
# [118]	validation_0-rmse:1526.34755
# [119]	validation_0-rmse:1527.58554
# [120]	validation_0-rmse:1527.96294
# [121]	validation_0-rmse:1528.65976
# [122]	validation_0-rmse:1528.57478
# [123]	validation_0-rmse:1528.48637
# [124]	validation_0-rmse:1528.22240
# [125]	validation_0-rmse:1528.16844
# [126]	validation_0-rmse:1528.32957
# [127]	validation_0-rmse:1528.35700
# [128]	validation_0-rmse:1528.37309
# [129]	validation_0-rmse:1528.35916
# [130]	validation_0-rmse:1528.38712
# [131]	validation_0-rmse:1528.43975
# [132]	validation_0-rmse:1528.54065
# [133]	validation_0-rmse:1528.50807
# [134]	validation_0-rmse:1528.46164
# [135]	validation_0-rmse:1528.66588
# [136]	validation_0-rmse:1529.14173
# [137]	validation_0-rmse:1528.56036
# [138]	validation_0-rmse:1528.80873
# [139]	validation_0-rmse:1528.83636
# [140]	validation_0-rmse:1529.10611
# [141]	validation_0-rmse:1529.08933
# [142]	validation_0-rmse:1529.11320
# [143]	validation_0-rmse:1529.41140
# [144]	validation_0-rmse:1529.95236
# [145]	validation_0-rmse:1530.00973
# [146]	validation_0-rmse:1529.10734
# [147]	validation_0-rmse:1529.53069
# [148]	validation_0-rmse:1529.41449
# [149]	validation_0-rmse:1529.38121
# [150]	validation_0-rmse:1529.57080
# [151]	validation_0-rmse:1529.41432
# [152]	validation_0-rmse:1529.38125
# [153]	validation_0-rmse:1529.74513
# [154]	validation_0-rmse:1529.74266
# [155]	validation_0-rmse:1529.14452
# [156]	validation_0-rmse:1529.34598
# [157]	validation_0-rmse:1529.72395
# [158]	validation_0-rmse:1529.79193
# [159]	validation_0-rmse:1530.02628
# [160]	validation_0-rmse:1530.25312
# [161]	validation_0-rmse:1529.89200
# [162]	validation_0-rmse:1529.78684
# [163]	validation_0-rmse:1529.88104
# [164]	validation_0-rmse:1530.92662
# [165]	validation_0-rmse:1530.81992
# [166]	validation_0-rmse:1530.83071
# [167]	validation_0-rmse:1530.99493
# [168]	validation_0-rmse:1531.36197
# [169]	validation_0-rmse:1531.19635
# [170]	validation_0-rmse:1531.40646
# [171]	validation_0-rmse:1528.67961
# [172]	validation_0-rmse:1530.15975
# [173]	validation_0-rmse:1530.50779
# [174]	validation_0-rmse:1530.51792
# [175]	validation_0-rmse:1530.88546
# [176]	validation_0-rmse:1531.14813
# [177]	validation_0-rmse:1531.46660
# [178]	validation_0-rmse:1531.90596
# [179]	validation_0-rmse:1531.81318
# [180]	validation_0-rmse:1531.65509
# [181]	validation_0-rmse:1531.73610
# [182]	validation_0-rmse:1531.79641
# [183]	validation_0-rmse:1532.30583
# [184]	validation_0-rmse:1532.45489
# [185]	validation_0-rmse:1532.70287
# [186]	validation_0-rmse:1532.66561
# [187]	validation_0-rmse:1532.72027
# [188]	validation_0-rmse:1532.74976
# [189]	validation_0-rmse:1532.83668
# [190]	validation_0-rmse:1533.42320
# [191]	validation_0-rmse:1533.37705
# [192]	validation_0-rmse:1533.51434
# [193]	validation_0-rmse:1533.82244
# [194]	validation_0-rmse:1533.87422
# [195]	validation_0-rmse:1533.67862
# [196]	validation_0-rmse:1533.69978
# [197]	validation_0-rmse:1533.62383
# [198]	validation_0-rmse:1533.74095
# [199]	validation_0-rmse:1534.25204
# [200]	validation_0-rmse:1533.84092
# [201]	validation_0-rmse:1533.89023
# [202]	validation_0-rmse:1533.75249
# [203]	validation_0-rmse:1533.81162
# [204]	validation_0-rmse:1534.11215
# [205]	validation_0-rmse:1532.68353
# [206]	validation_0-rmse:1532.76187
# [207]	validation_0-rmse:1532.47442
# [208]	validation_0-rmse:1532.98939
# [209]	validation_0-rmse:1533.08484
# [210]	validation_0-rmse:1533.56943
# [211]	validation_0-rmse:1533.74489
# [212]	validation_0-rmse:1534.16638
# [213]	validation_0-rmse:1534.52084
# [214]	validation_0-rmse:1534.74023
# [215]	validation_0-rmse:1535.13298
# [216]	validation_0-rmse:1535.12429
# [217]	validation_0-rmse:1535.23311
# [218]	validation_0-rmse:1535.67575
# [219]	validation_0-rmse:1536.05660
# [220]	validation_0-rmse:1536.01777
# [221]	validation_0-rmse:1536.19737
# [222]	validation_0-rmse:1536.19491
# [223]	validation_0-rmse:1536.28813
# [224]	validation_0-rmse:1536.48280
# [225]	validation_0-rmse:1536.52840
# [226]	validation_0-rmse:1536.50472
# [227]	validation_0-rmse:1536.32852
# [228]	validation_0-rmse:1536.73284
# [229]	validation_0-rmse:1536.77650
# [230]	validation_0-rmse:1537.40864
# [231]	validation_0-rmse:1537.30878
# [232]	validation_0-rmse:1537.38869
# [233]	validation_0-rmse:1537.28709
# [234]	validation_0-rmse:1537.28087
# [235]	validation_0-rmse:1537.65264
# [236]	validation_0-rmse:1538.03323
# [237]	validation_0-rmse:1538.12138
# [238]	validation_0-rmse:1538.11164
# [239]	validation_0-rmse:1538.26091
# [240]	validation_0-rmse:1538.36280
# [241]	validation_0-rmse:1538.39622
# [242]	validation_0-rmse:1538.41820
# [243]	validation_0-rmse:1538.56701
# [244]	validation_0-rmse:1538.37236
# [245]	validation_0-rmse:1538.41141
# [246]	validation_0-rmse:1538.36508
# [247]	validation_0-rmse:1538.67588
# [248]	validation_0-rmse:1538.95397
# [249]	validation_0-rmse:1538.40436

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7157283740835436
# Mean Absolute Error: 976.2706119747071
# Mean Squared Error: 2366687.9791630553
# Root Mean Squared Error: 1538.4043613962667
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# ## **Modelo cantidad**

# %%
# Merge a ambos dataframes
vuelos_ventas = pd.merge(ventas, vuelos, on="Flight_ID")
vuelos_ventas.drop(columns=["index", "Aeronave"], inplace=True)

# %%
vuelos_ventas["STD"] = pd.to_datetime(vuelos_ventas["STD"])
vuelos_ventas["STA"] = pd.to_datetime(vuelos_ventas["STA"])
vuelos_ventas["Duracion"] = vuelos_ventas["STA"] - vuelos_ventas["STD"]
vuelos_ventas["Duracion"] = vuelos_ventas["Duracion"].dt.total_seconds() / 60
vuelos_ventas["Hora"] = vuelos_ventas["STD"].dt.hour
vuelos_ventas["Dia"] = vuelos_ventas["STD"].dt.day
# Cambiar tipos de destinos a one-hot encoding
destination_type = vuelos_ventas["Destination_Type"].map(
    {
        "Ciudad Principal": "destino_ciudadprincipal",
        "Playa": "destino_playa",
        "MX Amigos y Familia": "destino_amigosfamilia",
        "Ciudad Fronteriza": "destino_ciudadfronteriza",
        "Ecoturismo": "destino_ecoturismo",
    }
)
destination_type = pd.get_dummies(destination_type, dtype="int")
vuelos_ventas = (
    pd.concat([vuelos_ventas, destination_type], axis=1)
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas = (
    vuelos_ventas.drop(columns=["Destination_Type"])
    if "Destination_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
origen_type = vuelos_ventas["Origin_Type"].map(
    {
        "Ciudad Principal": "origen_ciudadprincipal",
        "Playa": "origen_playa",
        "MX Amigos y Familia": "origen_amigosfamilia",
        "Ciudad Fronteriza": "origen_ciudadfronteriza",
        "Ecoturismo": "origen_ecoturismo",
    }
)
origen_type = pd.get_dummies(origen_type, dtype="int")
vuelos_ventas = (
    pd.concat([vuelos_ventas, origen_type], axis=1)
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas = (
    vuelos_ventas.drop(columns=["Origin_Type"])
    if "Origin_Type" in vuelos_ventas.columns
    else vuelos_ventas
)
vuelos_ventas["Book_Pass"] = vuelos_ventas["Bookings"] / vuelos_ventas["Passengers"]
vuelos_ventas.drop(columns=["STD", "STA"], inplace=True)
vuelos_ventas = one_hot_encode(vuelos_ventas, "DepartureStation", "departure")
vuelos_ventas = one_hot_encode(vuelos_ventas, "ArrivalStation", "arrival")

# %%
vuelos_ventas.drop(columns=["Flight_ID", "ProductType", "TotalSales"], inplace=True)

# %%
product_dict = {}
for i in vuelos_ventas["ProductName"].unique():
    product_dict[i] = len(product_dict)
vuelos_ventas["ProductName"] = vuelos_ventas["ProductName"].map(product_dict)

# %%
modelo2 = vuelos_ventas[vuelos_ventas["ProductName"] == 0]

# %%
X = modelo2.drop(columns=["Quantity"])
y = modelo2["Quantity"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0,
)

eval_set = [(x_test, y_test)]

train_dmatrix = xg.DMatrix(data=x_train, label=y_train)
test_dmatrix = xg.DMatrix(data=x_test, label=y_test)

# xgb_r = XGBRegressor(n_estimators=10, seed=123)
xgb_r = XGBRegressor(learning_rate=0.3, n_estimators=250)
xgb_r.fit(x_train, y_train, eval_set=eval_set, verbose=True)
y_pred = xgb_r.predict(x_test)
# Out:
# [0]	validation_0-rmse:0.77143
# [1]	validation_0-rmse:0.77220
# [2]	validation_0-rmse:0.77227
# [3]	validation_0-rmse:0.77110
# [4]	validation_0-rmse:0.77402
# [5]	validation_0-rmse:0.77702
# [6]	validation_0-rmse:0.77648
# [7]	validation_0-rmse:0.78009
# [8]	validation_0-rmse:0.78139
# [9]	validation_0-rmse:0.78207
# [10]	validation_0-rmse:0.78320
# [11]	validation_0-rmse:0.78437
# [12]	validation_0-rmse:0.78493
# [13]	validation_0-rmse:0.78782
# [14]	validation_0-rmse:0.78636
# [15]	validation_0-rmse:0.78753
# [16]	validation_0-rmse:0.78765
# [17]	validation_0-rmse:0.78886
# [18]	validation_0-rmse:0.79045
# [19]	validation_0-rmse:0.79078
# [20]	validation_0-rmse:0.78984
# [21]	validation_0-rmse:0.79164
# [22]	validation_0-rmse:0.79280
# [23]	validation_0-rmse:0.79248
# [24]	validation_0-rmse:0.79195
# [25]	validation_0-rmse:0.79265
# [26]	validation_0-rmse:0.79451
# [27]	validation_0-rmse:0.79519
# [28]	validation_0-rmse:0.79500
# [29]	validation_0-rmse:0.79571
# [30]	validation_0-rmse:0.79759
# [31]	validation_0-rmse:0.79950
# [32]	validation_0-rmse:0.80000
# [33]	validation_0-rmse:0.80117
# [34]	validation_0-rmse:0.80223
# [35]	validation_0-rmse:0.80377
# [36]	validation_0-rmse:0.80447
# [37]	validation_0-rmse:0.80465
# [38]	validation_0-rmse:0.80652
# [39]	validation_0-rmse:0.80642
# [40]	validation_0-rmse:0.80528
# [41]	validation_0-rmse:0.80566
# [42]	validation_0-rmse:0.80538
# [43]	validation_0-rmse:0.80642
# [44]	validation_0-rmse:0.80564
# [45]	validation_0-rmse:0.80552
# [46]	validation_0-rmse:0.80550
# [47]	validation_0-rmse:0.80645
# [48]	validation_0-rmse:0.80665
# [49]	validation_0-rmse:0.80700
# [50]	validation_0-rmse:0.80786
# [51]	validation_0-rmse:0.80812
# [52]	validation_0-rmse:0.80709
# [53]	validation_0-rmse:0.80679
# [54]	validation_0-rmse:0.80700
# [55]	validation_0-rmse:0.80531
# [56]	validation_0-rmse:0.80515
# [57]	validation_0-rmse:0.80511
# [58]	validation_0-rmse:0.80509
# [59]	validation_0-rmse:0.80457
# [60]	validation_0-rmse:0.80481
# [61]	validation_0-rmse:0.80501
# [62]	validation_0-rmse:0.80515
# [63]	validation_0-rmse:0.80565
# [64]	validation_0-rmse:0.80587
# [65]	validation_0-rmse:0.80601
# [66]	validation_0-rmse:0.80602
# [67]	validation_0-rmse:0.80695
# [68]	validation_0-rmse:0.80650
# [69]	validation_0-rmse:0.80627
# [70]	validation_0-rmse:0.80583
# [71]	validation_0-rmse:0.80595
# [72]	validation_0-rmse:0.80695
# [73]	validation_0-rmse:0.80679
# [74]	validation_0-rmse:0.80692
# [75]	validation_0-rmse:0.80742
# [76]	validation_0-rmse:0.80819
# [77]	validation_0-rmse:0.80848
# [78]	validation_0-rmse:0.80829
# [79]	validation_0-rmse:0.80904
# [80]	validation_0-rmse:0.80991
# [81]	validation_0-rmse:0.81050
# [82]	validation_0-rmse:0.81048
# [83]	validation_0-rmse:0.81016
# [84]	validation_0-rmse:0.81043
# [85]	validation_0-rmse:0.81083
# [86]	validation_0-rmse:0.81076
# [87]	validation_0-rmse:0.81137
# [88]	validation_0-rmse:0.81206
# [89]	validation_0-rmse:0.81303
# [90]	validation_0-rmse:0.81275
# [91]	validation_0-rmse:0.81375
# [92]	validation_0-rmse:0.81487
# [93]	validation_0-rmse:0.81397
# [94]	validation_0-rmse:0.81414
# [95]	validation_0-rmse:0.81496
# [96]	validation_0-rmse:0.81511
# [97]	validation_0-rmse:0.81509
# [98]	validation_0-rmse:0.81511
# [99]	validation_0-rmse:0.81497
# [100]	validation_0-rmse:0.81534
# [101]	validation_0-rmse:0.81553
# [102]	validation_0-rmse:0.81593
# [103]	validation_0-rmse:0.81602
# [104]	validation_0-rmse:0.81628
# [105]	validation_0-rmse:0.81661
# [106]	validation_0-rmse:0.81698
# [107]	validation_0-rmse:0.81694
# [108]	validation_0-rmse:0.81725
# [109]	validation_0-rmse:0.81800
# [110]	validation_0-rmse:0.81808
# [111]	validation_0-rmse:0.81782
# [112]	validation_0-rmse:0.81783
# [113]	validation_0-rmse:0.81796
# [114]	validation_0-rmse:0.81811
# [115]	validation_0-rmse:0.81787
# [116]	validation_0-rmse:0.81869
# [117]	validation_0-rmse:0.81912
# [118]	validation_0-rmse:0.81830
# [119]	validation_0-rmse:0.81870
# [120]	validation_0-rmse:0.81890
# [121]	validation_0-rmse:0.81984
# [122]	validation_0-rmse:0.81954
# [123]	validation_0-rmse:0.81989
# [124]	validation_0-rmse:0.81973
# [125]	validation_0-rmse:0.81964
# [126]	validation_0-rmse:0.81961
# [127]	validation_0-rmse:0.81961
# [128]	validation_0-rmse:0.82024
# [129]	validation_0-rmse:0.82069
# [130]	validation_0-rmse:0.82084
# [131]	validation_0-rmse:0.82114
# [132]	validation_0-rmse:0.82159
# [133]	validation_0-rmse:0.82192
# [134]	validation_0-rmse:0.82202
# [135]	validation_0-rmse:0.82169
# [136]	validation_0-rmse:0.82195
# [137]	validation_0-rmse:0.82261
# [138]	validation_0-rmse:0.82257
# [139]	validation_0-rmse:0.82263
# [140]	validation_0-rmse:0.82304
# [141]	validation_0-rmse:0.82308
# [142]	validation_0-rmse:0.82310
# [143]	validation_0-rmse:0.82340
# [144]	validation_0-rmse:0.82363
# [145]	validation_0-rmse:0.82406
# [146]	validation_0-rmse:0.82380
# [147]	validation_0-rmse:0.82392
# [148]	validation_0-rmse:0.82432
# [149]	validation_0-rmse:0.82470
# [150]	validation_0-rmse:0.82491
# [151]	validation_0-rmse:0.82488
# [152]	validation_0-rmse:0.82525
# [153]	validation_0-rmse:0.82527
# [154]	validation_0-rmse:0.82558
# [155]	validation_0-rmse:0.82574
# [156]	validation_0-rmse:0.82568
# [157]	validation_0-rmse:0.82579
# [158]	validation_0-rmse:0.82576
# [159]	validation_0-rmse:0.82609
# [160]	validation_0-rmse:0.82655
# [161]	validation_0-rmse:0.82660
# [162]	validation_0-rmse:0.82685
# [163]	validation_0-rmse:0.82702
# [164]	validation_0-rmse:0.82656
# [165]	validation_0-rmse:0.82668
# [166]	validation_0-rmse:0.82662
# [167]	validation_0-rmse:0.82659
# [168]	validation_0-rmse:0.82650
# [169]	validation_0-rmse:0.82678
# [170]	validation_0-rmse:0.82671
# [171]	validation_0-rmse:0.82719
# [172]	validation_0-rmse:0.82732
# [173]	validation_0-rmse:0.82798
# [174]	validation_0-rmse:0.82806
# [175]	validation_0-rmse:0.82840
# [176]	validation_0-rmse:0.82803
# [177]	validation_0-rmse:0.82796
# [178]	validation_0-rmse:0.82805
# [179]	validation_0-rmse:0.82810
# [180]	validation_0-rmse:0.82829
# [181]	validation_0-rmse:0.82821
# [182]	validation_0-rmse:0.82824
# [183]	validation_0-rmse:0.82812
# [184]	validation_0-rmse:0.82848
# [185]	validation_0-rmse:0.82849
# [186]	validation_0-rmse:0.82863
# [187]	validation_0-rmse:0.82874
# [188]	validation_0-rmse:0.82881
# [189]	validation_0-rmse:0.82883
# [190]	validation_0-rmse:0.82900
# [191]	validation_0-rmse:0.82890
# [192]	validation_0-rmse:0.82922
# [193]	validation_0-rmse:0.82915
# [194]	validation_0-rmse:0.82966
# [195]	validation_0-rmse:0.82954
# [196]	validation_0-rmse:0.82969
# [197]	validation_0-rmse:0.82982
# [198]	validation_0-rmse:0.83008
# [199]	validation_0-rmse:0.83004
# [200]	validation_0-rmse:0.83023
# [201]	validation_0-rmse:0.83031
# [202]	validation_0-rmse:0.83043
# [203]	validation_0-rmse:0.83047
# [204]	validation_0-rmse:0.83053
# [205]	validation_0-rmse:0.83068
# [206]	validation_0-rmse:0.83063
# [207]	validation_0-rmse:0.83074
# [208]	validation_0-rmse:0.83068
# [209]	validation_0-rmse:0.83069
# [210]	validation_0-rmse:0.83059
# [211]	validation_0-rmse:0.83083
# [212]	validation_0-rmse:0.83073
# [213]	validation_0-rmse:0.83096
# [214]	validation_0-rmse:0.83088
# [215]	validation_0-rmse:0.83077
# [216]	validation_0-rmse:0.83075
# [217]	validation_0-rmse:0.83082
# [218]	validation_0-rmse:0.83093
# [219]	validation_0-rmse:0.83095
# [220]	validation_0-rmse:0.83108
# [221]	validation_0-rmse:0.83111
# [222]	validation_0-rmse:0.83123
# [223]	validation_0-rmse:0.83128
# [224]	validation_0-rmse:0.83103
# [225]	validation_0-rmse:0.83108
# [226]	validation_0-rmse:0.83122
# [227]	validation_0-rmse:0.83104
# [228]	validation_0-rmse:0.83108
# [229]	validation_0-rmse:0.83125
# [230]	validation_0-rmse:0.83137
# [231]	validation_0-rmse:0.83150
# [232]	validation_0-rmse:0.83149
# [233]	validation_0-rmse:0.83151
# [234]	validation_0-rmse:0.83140
# [235]	validation_0-rmse:0.83145
# [236]	validation_0-rmse:0.83166
# [237]	validation_0-rmse:0.83157
# [238]	validation_0-rmse:0.83159
# [239]	validation_0-rmse:0.83165
# [240]	validation_0-rmse:0.83168
# [241]	validation_0-rmse:0.83169
# [242]	validation_0-rmse:0.83169
# [243]	validation_0-rmse:0.83171
# [244]	validation_0-rmse:0.83173
# [245]	validation_0-rmse:0.83156
# [246]	validation_0-rmse:0.83153
# [247]	validation_0-rmse:0.83165
# [248]	validation_0-rmse:0.83163
# [249]	validation_0-rmse:0.83171

# %%
# Evaluamos el modelo
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: -0.16427295425310406
# Mean Absolute Error: 0.5320833884361313
# Mean Squared Error: 0.6917398586424164
# Root Mean Squared Error: 0.831708998774461
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Franco Mendoza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
